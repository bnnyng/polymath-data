# %% [markdown]
# Code to scrape all comments and main posts of Polymath projects.

# %% [markdown]
# # Preliminaries

# %%
# ! pip install requests beautifulsoup4

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from urllib.parse import urljoin
from google.colab import files

# %%
column_order = [
    'id',
    'time',
    'in-reply-to',
    'in-reply-to-href',
    'author',
    'author-href',
    'comment-id',
    'comment-href',
    'post-id',
    'content'
]

# %% [markdown]
# # Functions

# %%
###  PARSING  ###

def get_site_for_url(url):
    if 'en.wikipedia.org' in url:
        return 'W'
    elif 'gowers.wordpress.com' in url:
        return 'G'
    elif 'terrytao.wordpress.com' in url:
        return 'T'
    elif 'gilkalai.wordpress.com' in url:
        return 'K'
    elif 'dustingmixon.wordpress.com' in url:
        return 'D'
    elif 'sbseminar.wordpress.com' in url:
        return 'M'
    else:
        return 'P'

def parse_url_file(urls_path='urls.txt'):
    with open(urls_path, 'r') as file:
        lines = file.read().strip().split()

    project_urls_dict = {}
    curr = None
    for line in lines:
        if line.startswith('POLYMATH') or line.startswith('MINI'):
            curr = line[0] + ''.join(re.findall(r'\d+', line))
            project_urls_dict[curr] = []
        elif line != '':
            project_urls_dict[curr].append((get_site_for_url(line), line))
    return project_urls_dict

def parse_urls(urls):
    """
    """
    url_list = [url.strip() for url in urls.strip().split('\n')]
    blog_url_pairs = []
    for url in url_list:
        if 'gowers.wordpress.com' in url:
            blog = 'G'
        elif 'terrytao.wordpress.com' in url:
            blog = 'T'
        elif 'gilkalai.wordpress.com' in url:
            blog = 'K'
        elif 'dustingmixon.wordpress.com' in url:
            blog = 'D'
        elif 'sbseminar.wordpress.com' in url:
            blog = 'M'
        else:
            blog = 'P'
        blog_url_pairs.append((blog, url))
    return blog_url_pairs

def parse_datetime(datetime_str):
    try:
        # Gowers, Gil Kalai blog format
        # Example: 'February 1, 2009 at 8:59 pm'
        dt = datetime.strptime(datetime_str, '%B %d, %Y at %I:%M %p')
    except ValueError:
        try:
            # Tao blog format
            # Example: '23 May, 2009 at 10:42 am'
            dt = datetime.strptime(datetime_str, '%d %B, %Y at %I:%M %p')
        except ValueError:
            try:
                # Polymath blog format
                # Example: 'July 12, 2012 @10:11 pm'
                dt = datetime.strptime(datetime_str, '%B %d, %Y @%I:%M %p')
            except:
                raise ValueError(f'Unknown format: {datetime_str}')

    return dt

# %%
###  POST SCRAPING  ###

def scrape_all_posts(url_dict):
    post_dict = {
        'project-id' : [],
        'post-id' : [],
        'post-href' : [],
        'paragraph-idx' : [],
        'paragraph-content' : []
    }

    for project, urls in url_dict.items():
        for (blog, url) in urls:
            paragraphs, soup = scrape_page(blog, url)
            post_id_tag = soup.find(
                (lambda tag : tag.has_attr('id') and tag['id'].startswith('post'))
            )
            post_id = post_id_tag['id'].split('-')[1]
            for i, p in enumerate(paragraphs):
                post_dict['project-id'].append(project)
                post_dict['post-id'].append(blog + post_id)
                post_dict['post-href'].append(url)
                post_dict['paragraph-idx'].append(str(i))
                post_dict['paragraph-content'].append(p)
        print(f'PROJECT {project} COMPLETE. \n')
    df = pd.DataFrame(post_dict)
    df['id'] = df['project-id'] + '-' + df['post-id'] + '-' + df['paragraph-idx']
    return df

# %%
###  COMMENT SCRAPING  ###

def get_child_ids(blog, comment):
    if blog == 'T':
        # Replies are in a 'sibling' environment
        reply_env = comment.find_next_sibling(class_='children')
    else:
        # Replies are nested in the parent enviornment
        reply_env = comment.find(class_='children')
    try:
        reply_tag = reply_env.find_all(
            id=lambda x : x and x.startswith('comment-')
        )
        reply_ids = [
            reply['id'].split('-')[-1]
            for reply in reply_tag
        ]
    except AttributeError:
        reply_ids = None

    return reply_ids

def scrape_comments(blog, base_url, comments):
    """
    Helper function for scraping the comments of a single thread (blog post).
    Returns a DataFrame with the following data:
        - author
        - author-href
        - time
        - comment-href
        - comment-id
        - content
        - child-ids

    Parameters
    ----------
    blog : String
        Character representation of source blog; Gowers (G), Tao (T), Polymath
        projects blog (P)
    comments : ResultSet
    """
    comment_dict = {
        'author' : [],
        'author-href' : [],
        'time' : [],
        'comment-href' : [],
        'comment-id' : [],
        'content' : [],
        'child-ids' : []
    }

    for comment in comments:
        comment_id = comment['id'].split('-')[-1]

        if blog == 'G':
            # Gowers' blog
            cite_tag = comment.find('cite')
            author = cite_tag.get_text(strip=True)
            author_href = (
                cite_tag.find('a')['href']
                if cite_tag.find('a') else None
            )
            metadata_tag = comment.find('small')
            datetime_tag = metadata_tag.find('a', href=str('#comment-' + comment_id))
            datetime_str = datetime_tag.get_text(strip=True)
            comment_href = urljoin(base_url, metadata_tag.find('a')['href'])
            content_tag = comment.find_all('p')
        elif blog == 'T':
            # Tao's blog
            author_tag = comment.find(class_='comment-author').strong
            author = author_tag.get_text(strip=True)
            author_href = (
                author_tag.find('a')['href']
                if author_tag.find('a') else None
            )
            datetime_tag = comment.find(class_='comment-permalink')
            datetime_str = datetime_tag.get_text(strip=True)
            comment_href = comment.find(class_='comment-permalink').find('a')['href']
            content_tag = comment.find(class_='comment-content')
        elif blog == 'K':
            # Gil Kalai's blog
            author_tag = comment.find(class_=lambda x : x and x.startswith('comment-author'))
            cite_tag = author_tag.find('cite')
            author = cite_tag.get_text(strip=True)
            author_href = (
                cite_tag.find('a')['href']
                if cite_tag.find('a') else None
            )
            metadata_tag = comment.find(class_=lambda x : x and x.startswith('comment-meta'))
            datetime_str = metadata_tag.get_text(strip=True)
            comment_href = metadata_tag.find('a')['href']
            content_tag = comment.find(class_='comment-body')
        elif blog == 'D' or blog == 'M':
            # Dustin Mixon's blog
            comment_tag = comment.find(class_='comment-body').find(class_='comment-meta')
            author_tag = comment_tag.find(
                class_=lambda x : x and x.startswith('comment-author')
            )
            if blog == 'D':
                author_tag = author_tag.find('b', class_='fn')
            else:
                author_tag = author_tag.find('cite', class_='fn')
            author = author_tag.get_text(strip=True)
            author_href = (
                author_tag.find('a')['href']
                if author_tag.find('a') else None
            )
            metadata_tag = comment_tag.find(class_='comment-metadata')
            datetime_str = metadata_tag.find('time').get_text(strip=True)
            comment_href = metadata_tag.find('a')['href']
            content_tag = comment.find(class_='comment-content')
        else:
            # Polymath projects blog
            metadata_tag = comment.find(
                id=lambda x : x and x.startswith('pd_rating_holder')
            ).find_next_sibling('p').find('cite')
            author_tag = metadata_tag.find('span', class_='fn')
            author = author_tag.get_text(strip=True)
            author_href = (
                author_tag.find('a')['href']
                if author_tag.find('a') else None
            )
            datetime_str = metadata_tag.get_text(strip=True).split('— ')[-1]
            for a in metadata_tag('a', href=True):
                if a['href'].startswith('#comment-'):
                    comment_href = urljoin(base_url, a['href'])
            content_tag = comment.find(
                class_=lambda x : x and x.startswith('comment-author')
            )

        # Get comment content
        content_list = []
        if blog == 'P':
            for child in content_tag:
                if child.name == 'div':
                    break
                content_list.append(child.get_text(separator=' ', strip=True))
        else:
            for p in content_tag:
                content_list.append(p.get_text(separator=' ', strip=True))
        content = ' '.join(content_list)
        content = ' '.join(content.split()) # remove extra whitespace

        reply_ids = get_child_ids(blog, comment)

        # Store data in dictionary
        comment_dict['author'].append(author)
        comment_dict['author-href'].append(author_href)
        comment_dict['time'].append(parse_datetime(datetime_str))
        comment_dict['comment-href'].append(comment_href)
        comment_dict['comment-id'].append(comment_id)
        comment_dict['content'].append(content)
        comment_dict['child-ids'].append(reply_ids)
    return pd.DataFrame(comment_dict)

def scrape_page(blog, url):
    """
    Given a single page of comments, returns a DataFrame with the
    following data for each comment: TBD

    Parameters
    ----------
    blog : String
    url : String
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Check for comment pagination
    nav_tag = soup.find('div', class_='navigation')
    if nav_tag and blog == 'T':
        next_tag = nav_tag.find('div', class_='alignleft').find('a')
        next_url = (next_tag['href'] if next_tag else None)
    else:
        next_url = None

    # Replace LaTeX figures with alt text
    tex_tag = soup.find_all('img', class_='latex')
    for t in tex_tag:
        alt = t.get('alt', '')
        t.replace_with('$' + alt + '$')

    # Get list of comments
    comment_tag = 'div' if blog == 'T' else 'li'
    comments = soup.find_all(
        comment_tag,
        class_=lambda x : x and x.startswith('comment'),
        id=lambda x : x and (x.startswith('comment-') or x.startswith('li-comment-'))
    )

    if comments:
        df = scrape_comments(blog, url, comments)
        df['blog'] = blog
        post_env = 'div'
        if blog == 'T':
            post_env = 'h1'
            # post_tag = soup.find('h1', id=lambda x :x and x.startswith('post'))
        elif blog == 'D' or blog == 'M':
            post_env = 'article'
            # post_tag = soup.find('article')
        post_tag = soup.find(post_env, id=lambda x : x and x.startswith('post'))
        df['post-id'] = post_tag['id'].split('-')[-1]
        return df, next_url

    return None

def scrape_thread(blog, url):
    """
    Concatenate and format data for all pages associated with a single thread.
    """
    df = pd.DataFrame()
    while url:
        df_comments, url = scrape_page(blog, url)
        df = pd.concat([df, df_comments], ignore_index=True)

    # Create custom ID
    df['id'] = df['blog'] + df['post-id'] + '-' + df['comment-id']

    # Get parent references
    df['in-reply-to'] = None
    df['in-reply-to-href'] = None
    for _, row in df.iterrows():
        parent_id = row['id']
        child_ids = row['child-ids']
        if child_ids:
            for child in child_ids:
                df.loc[df['comment-id'] == child, ['in-reply-to', 'in-reply-to-href']] = [row['id'], row['comment-href']]
    df.loc[df['in-reply-to'].notnull(), 'id'] = (
        df.loc[df['in-reply-to'].notnull(), 'blog'] + 'r' +
        df.loc[df['in-reply-to'].notnull(), 'post-id'] + '-' +
        df.loc[df['in-reply-to'].notnull(), 'comment-id']
    )

    return df

def scrape_project(thread_list):
    """
    """
    df = pd.DataFrame()
    for (blog, url) in thread_list:
        df_thread = scrape_thread(blog, url)
        df = pd.concat([df, df_thread], ignore_index=True)
    return df

# %%
###  SAVING  ###

def configure_columns(project_id, df):
    """
    Parameters
    ----------
    df : DataFrame
    column_order : list
    """
    df['project-id'] = project_id
    df['id'] = project_id + '-' + df['id']
    df['in-reply-to'] = project_id + '-' + df['in-reply-to']
    all_projects.append(df)
    return df

def download_df(df, output_name, format='json', index=False):
    if format == 'csv':
        df.to_csv(output_name, index=index)
    elif format == 'xlsx':
        df.to_excel(output_name, index=index)
    else:
        df.to_json(output_name, orient='records')
    files.download(output_name)

# %% [markdown]
# # Scrape posts

# %%
url_dict = parse_url_file()
df_posts = scrape(url_dict)
download_df(df_posts, 'data-project-posts.json')

# %% [markdown]
# # Scrape comments

# %% [markdown]
# ## Polymath1

# %%
poly1_thread_dict = {
    '1-199' : ('G', 'https://gowers.wordpress.com/2009/02/01/a-combinatorial-approach-to-density-hales-jewett/'),
    '200-299' : ('T', 'https://terrytao.wordpress.com/2009/02/05/upper-and-lower-bounds-for-the-density-hales-jewett-problem/'),
    '300-399' : ('G', 'https://gowers.wordpress.com/2009/02/06/dhj-the-triangle-removal-approach/'),
    '400-499' : ('G', 'https://gowers.wordpress.com/2009/02/08/dhj-quasirandomness-and-obstructions-to-uniformity/'),
    '500-599' : ('G', 'https://gowers.wordpress.com/2009/02/13/dhj-possible-proof-strategies/'),
    '600-699' : ('T', 'https://terrytao.wordpress.com/2009/02/11/a-reading-seminar-on-density-hales-jewett/'),
    '700-799' : ('T', 'https://terrytao.wordpress.com/2009/02/13/bounds-for-the-first-few-density-hales-jewett-numbers-and-related-quantities/'),
    '800-849' : ('G', 'http://gowers.wordpress.com/2009/02/23/brief-review-of-polymath1/'),
    '850-900' : ('G', 'https://gowers.wordpress.com/2009/03/02/dhj3-851-899/'),
    '900-999' : ('T', 'https://terrytao.wordpress.com/2009/03/04/dhj3-900-999-density-hales-jewett-type-numbers/'),
    '1000-1049' : ('G', 'https://gowers.wordpress.com/2009/03/10/problem-solved-probably/'),
    '1050-1099' : ('G', 'http://gowers.wordpress.com/2009/03/16/dhj3-and-related-results-1050-1099/'),
    '1100-1199' : ('T', 'https://terrytao.wordpress.com/2009/03/14/dhj3-1100-1199-density-hales-jewett-type-numbers/'),
    '1200-1299' : ('T', 'http://terrytao.wordpress.com/2009/03/30/dhjk-1200-1299-density-hales-jewett-type-numbers/')
}
poly1_thread_list = poly1_thread_dict.values()

# %%
df_poly1 = scrape_project(poly1_thread_list)
df_poly1 = configure_columns('P1', df_poly1)
df_poly1
# Out:
#                 author                         author-href  \
# 0               gowers        https://gowers.wordpress.com
# 1               jozsef                                None
# 2           Jason Dyer  http://numberwarrior.wordpress.com
# 3          Terence Tao       http://www.math.ucla.edu/~tao
# 4          Terence Tao       http://www.math.ucla.edu/~tao
# ...                ...                                 ...
# 1503         Gil Kalai      http://gilkalai.wordpress.com/
# 1504  Kristal Cantwell                                None
# 1505       D. Eppstein    http://11011110.livejournal.com/
# 1506       D. Eppstein    http://11011110.livejournal.com/
# 1507       D. Eppstein    http://11011110.livejournal.com/
#
#                     time                                       comment-href  \
# 0    2009-02-01 20:59:00  https://gowers.wordpress.com/2009/02/01/a-comb...
# 1    2009-02-01 21:08:00  https://gowers.wordpress.com/2009/02/01/a-comb...
# 2    2009-02-01 21:23:00  https://gowers.wordpress.com/2009/02/01/a-comb...
# 3    2009-02-01 21:26:00  https://gowers.wordpress.com/2009/02/01/a-comb...
# 4    2009-02-01 21:30:00  https://gowers.wordpress.com/2009/02/01/a-comb...
# ...                  ...                                                ...
# 1503 2009-04-04 23:28:00  https://terrytao.wordpress.com/2009/03/30/dhjk...
# 1504 2009-04-05 12:15:00  https://terrytao.wordpress.com/2009/03/30/dhjk...
# 1505 2009-04-05 13:57:00  https://terrytao.wordpress.com/2009/03/30/dhjk...
# 1506 2009-04-05 16:32:00  https://terrytao.wordpress.com/2009/03/30/dhjk...
# 1507 2009-04-05 16:50:00  https://terrytao.wordpress.com/2009/03/30/dhjk...
#
#      comment-id                                            content child-ids  \
# 0          1646  1. A quick question. Furstenberg and Katznelso...      None
# 1          1648  2. In this note I will try to argue that we sh...      None
# 2          1649  3. I find it reassuring the first thing I thou...      None
# 3          1650  4. As Gil pointed out in his post on this proj...      None
# 4          1651  5. Incidentally, I only learned in the process...      None
# ...         ...                                                ...       ...
# 1503      37905  1240. re: David’s 1218 There are some studies ...      None
# 1504      37922  1241. 4D Moser If a Moser set has 4 points wit...      None
# 1505      37925  1242. Fujimura disjoint triangle cover Ok, let...      None
# 1506      37930  1243. Fujimura disjoint triangle cover I forgo...      None
# 1507      37938  1244. Fujimura disjoint triangle cover Ok, aft...      None
#
#      blog post-id              id in-reply-to in-reply-to-href project-id
# 0       G     300    P1-G300-1646         NaN             None         P1
# 1       G     300    P1-G300-1648         NaN             None         P1
# 2       G     300    P1-G300-1649         NaN             None         P1
# 3       G     300    P1-G300-1650         NaN             None         P1
# 4       G     300    P1-G300-1651         NaN             None         P1
# ...   ...     ...             ...         ...              ...        ...
# 1503    T    1984  P1-T1984-37905         NaN             None         P1
# 1504    T    1984  P1-T1984-37922         NaN             None         P1
# 1505    T    1984  P1-T1984-37925         NaN             None         P1
# 1506    T    1984  P1-T1984-37930         NaN             None         P1
# 1507    T    1984  P1-T1984-37938         NaN             None         P1
#
# [1508 rows x 13 columns]

# %%
# Check: Gower replies
# df_poly1[df_poly1['id'] == 'P1-G499-2925']
# df_poly1[df_poly1['in-reply-to'] == 'P1-G499-2925']

# %%
# Check: Gower LaTeX parsing
df_poly1[df_poly1['comment-id'] == '1658']['content'].iloc[0]
# Out:
# '7. With reference to Jozsef’s comment, if we suppose that the $d$ numbers used to generate the set are indeed independent, then it’s natural to label a typical point of the Cartesian product as $(\\epsilon,\\eta)$ , where each of $\\epsilon$ and $\\eta$ is a $01$ -sequence of length $d$ . Then a corner is a triple of the form $(\\epsilon,\\eta)$ , $(\\epsilon,\\eta+\\delta)$ , $(\\epsilon+\\delta,\\eta)$ , where $\\delta$ is a $\\{-1,0,1\\}$ -valued sequence of length $d$ with the property that both $\\epsilon+\\delta$ and $\\eta+\\delta$ are $01$ -sequences. So the question is whether corners exist in every dense subset of the original Cartesian product. This is simpler than the density Hales-Jewett problem in at least one respect: it involves $01$ -sequences rather than $012$ -sequences. But that simplicity may be slightly misleading because we are looking for corners in the Cartesian product. A possible disadvantage is that in this formulation we lose the symmetry of the corners: the horizontal and vertical lines will intersect this set in a different way from how the lines of slope -1 do. I feel that this is a promising avenue to explore, but I would also like a little more justification of the suggestion that this variant is likely to be simpler.'

# %%
# Check: Tao LaTeX parsing
df_poly1[df_poly1['comment-id'] == '35662']['content'].iloc[0]
# Out:
# '241. Upper bound for $c_5 < 156$ This proof is along the lines of Sune.90 Sune shows there is just one way to place 18 points in a cube, and that at most 52 points fit in $3^4$ Suppose 156 points may be chosen in $3^5$ . There must be 52 points in each slice of $3^4$ Divide $3^5$ into nine cubes. There are 17 or 18 points in each cube, and one cube in each row and column has 18 points. For example 17, 17, 18 18, 17, 17 17, 18, 17 Cut the cubes further, into squares. The 18-point cubes must cut into three six-point slices x y and z, but the 17-point squares have more variation pqr, stu, xyz xyz, abc, def ghk, xyz, lmn Take the three cubes in the top row, and slice them along a different axis so they are psx, qty and ruz. One of these cubes has 18 points, and so is xyz; so r=x and u=y. Similar logic in second column gives u=x and c=y. So there is a contradiction. There are four other ways to place the 17-point and 18-point cubes, but they all lead to contradictions. So 156 points can’t be placed in $3^5$'

# %%
# TO DO: row without content
# row = df_poly1.loc[df_poly1['comment-id'] == '2398']

# %%
download_df(df_poly1, 'polymath1.json')

# %% [markdown]
# ## Polymath2

# %%
df_poly2 = scrape_project([('G', 'https://gowers.wordpress.com/2009/02/17/must-an-explicitly-defined-banach-space-contain-c_0-or-ell_p/')])
df_poly2 = configure_columns('P2', df_poly2)
df_poly2
# Out:
#               author                                 author-href  \
# 0             gowers                https://gowers.wordpress.com
# 1     Alec Edgington                                        None
# 2             gowers                https://gowers.wordpress.com
# 3   toomuchcoffeeman  http://ifwisdomwereteachable.wordpress.com
# 4       Timothy Chow               http://alum.mit.edu/www/tchow
# ..               ...                                         ...
# 62  Mr NuttELAVer7Ya        http://mrnuttelaver7ya.wordpress.com
# 63  Mr NuttELAVer7Ya        http://mrnuttelaver7ya.wordpress.com
# 64  Mr NuttELAVer7Ya        http://mrnuttelaver7ya.wordpress.com
# 65  Mr NuttELAVer7Ya        http://mrnuttelaver7ya.wordpress.com
# 66  Mr NuttELAVer7Ya        http://mrnuttelaver7ya.wordpress.com
#
#                   time                                       comment-href  \
# 0  2009-02-18 09:53:00  https://gowers.wordpress.com/2009/02/17/must-a...
# 1  2009-02-18 16:12:00  https://gowers.wordpress.com/2009/02/17/must-a...
# 2  2009-02-18 19:42:00  https://gowers.wordpress.com/2009/02/17/must-a...
# 3  2009-02-20 02:42:00  https://gowers.wordpress.com/2009/02/17/must-a...
# 4  2009-02-20 04:01:00  https://gowers.wordpress.com/2009/02/17/must-a...
# ..                 ...                                                ...
# 62 2024-05-18 13:59:00  https://gowers.wordpress.com/2009/02/17/must-a...
# 63 2024-05-18 14:15:00  https://gowers.wordpress.com/2009/02/17/must-a...
# 64 2024-05-18 14:15:00  https://gowers.wordpress.com/2009/02/17/must-a...
# 65 2024-05-18 14:25:00  https://gowers.wordpress.com/2009/02/17/must-a...
# 66 2024-05-18 14:26:00  https://gowers.wordpress.com/2009/02/17/must-a...
#
#    comment-id                                            content child-ids  \
# 0        2252  1. A long time ago when I was thinking about t...      None
# 1        2256  Hello Tim. I too am looking forward to seeing ...      None
# 2        2258  Alec, Tim himself asked a similar question in ...      None
# 3        2285  Interesting discussion, though not one where I...      None
# 4        2287  Here’s one way to probe “how much induction” i...      None
# ..        ...                                                ...       ...
# 62     537496                         Fix him for her nvisaversa      None
# 63     537497                                                         None
# 64     537498                      Utwinprimeconjecture solved—-      None
# 65     537499  Obtain resolution through compromise in times ...      None
# 66     537500                                                         None
#
#    blog post-id              id in-reply-to in-reply-to-href project-id
# 0     G     449    P2-G449-2252         NaN             None         P2
# 1     G     449    P2-G449-2256         NaN             None         P2
# 2     G     449    P2-G449-2258         NaN             None         P2
# 3     G     449    P2-G449-2285         NaN             None         P2
# 4     G     449    P2-G449-2287         NaN             None         P2
# ..  ...     ...             ...         ...              ...        ...
# 62    G     449  P2-G449-537496         NaN             None         P2
# 63    G     449  P2-G449-537497         NaN             None         P2
# 64    G     449  P2-G449-537498         NaN             None         P2
# 65    G     449  P2-G449-537499         NaN             None         P2
# 66    G     449  P2-G449-537500         NaN             None         P2
#
# [67 rows x 13 columns]

# %%
download_df(df_poly2, 'polymath2.json')

# %% [markdown]
# ## Polymath3

# %%
poly3_urls = """
https://gilkalai.wordpress.com/2010/09/29/polymath-3-polynomial-hirsch-conjecture/
https://gilkalai.wordpress.com/2010/10/03/polymath-3-the-polynomial-hirsch-conjecture-2/
https://gilkalai.wordpress.com/2010/10/10/polymath3-polynomial-hirsch-conjecture-3/
https://gilkalai.wordpress.com/2010/10/21/polymath3-polynomial-hirsch-conjecture-4/
https://gilkalai.wordpress.com/2010/11/28/polynomial-hirsch-conjecture-5-abstractions-and-counterexamples/
https://gilkalai.wordpress.com/2011/04/13/polymath3-phc6-the-polynomial-hirsch-conjecture-a-topological-approach/
https://gilkalai.wordpress.com/2009/08/09/the-polynomial-hirsch-conjecture-discussion-thread/
https://gilkalai.wordpress.com/2009/10/06/the-polynomial-hirsch-conjecture-discussion-thread-continued/
"""
poly3_thread_list = parse_urls(poly3_urls)
poly3_thread_list
# Out:
# [('K',
#   'https://gilkalai.wordpress.com/2010/09/29/polymath-3-polynomial-hirsch-conjecture/'),
#  ('K',
#   'https://gilkalai.wordpress.com/2010/10/03/polymath-3-the-polynomial-hirsch-conjecture-2/'),
#  ('K',
#   'https://gilkalai.wordpress.com/2010/10/10/polymath3-polynomial-hirsch-conjecture-3/'),
#  ('K',
#   'https://gilkalai.wordpress.com/2010/10/21/polymath3-polynomial-hirsch-conjecture-4/'),
#  ('K',
#   'https://gilkalai.wordpress.com/2010/11/28/polynomial-hirsch-conjecture-5-abstractions-and-counterexamples/'),
#  ('K',
#   'https://gilkalai.wordpress.com/2011/04/13/polymath3-phc6-the-polynomial-hirsch-conjecture-a-topological-approach/'),
#  ('K',
#   'https://gilkalai.wordpress.com/2009/08/09/the-polynomial-hirsch-conjecture-discussion-thread/'),
#  ('K',
#   'https://gilkalai.wordpress.com/2009/10/06/the-polynomial-hirsch-conjecture-discussion-thread-continued/')]

# %%
df_poly3 = scrape_project(poly3_thread_list)
df_poly3 = configure_columns('P3', df_poly3)
df_poly3
# Out:
#              author                          author-href                time  \
# 0    Nicolai Hähnle                                 None 2010-09-30 12:52:00
# 1         Gil Kalai     http://www.ma.huji.ac.il/~kalai/ 2010-09-30 17:25:00
# 2    Nicolai Hähnle                                 None 2010-10-01 13:18:00
# 3       Terence Tao        http://www.math.ucla.edu/~tao 2010-09-30 19:32:00
# 4       Terence Tao        http://www.math.ucla.edu/~tao 2010-09-30 20:10:00
# ..              ...                                  ...                 ...
# 592           Oinky                                 None 2009-10-15 21:47:00
# 593  Anand Kulkarni  http://www.ocf.berkeley.edu/~anandk 2009-11-04 03:36:00
# 594       Gil Kalai     http://www.ma.huji.ac.il/~kalai/ 2009-11-06 01:07:00
# 595     realsamurai                http://smartfxsol.com 2010-08-01 12:50:00
# 596           草榴社区i        http://caoliuzuixindi.pen.io/ 2011-11-12 23:08:00
#
#                                           comment-href comment-id  \
# 0    https://gilkalai.wordpress.com/2010/09/29/poly...       3397
# 1    https://gilkalai.wordpress.com/2010/09/29/poly...       3398
# 2    https://gilkalai.wordpress.com/2010/09/29/poly...       3428
# 3    https://gilkalai.wordpress.com/2010/09/29/poly...       3399
# 4    https://gilkalai.wordpress.com/2010/09/29/poly...       3401
# ..                                                 ...        ...
# 592  https://gilkalai.wordpress.com/2009/10/06/the-...       1996
# 593  https://gilkalai.wordpress.com/2009/10/06/the-...       2048
# 594  https://gilkalai.wordpress.com/2009/10/06/the-...       2056
# 595  https://gilkalai.wordpress.com/2009/10/06/the-...       3320
# 596  https://gilkalai.wordpress.com/2009/10/06/the-...       5535
#
#                                                content child-ids blog post-id  \
# 0    Dear Gil, I’ve only recently thought about thi...      None    K    5439
# 1    Dear Nicolai, This is very interesting! Pleas ...    [3428]    K    5439
# 2    Here’s a construction giving d(n-1)+1 that par...      None    K    5439
# 3    I’ve started a wiki page for this project at h...      None    K    5439
# 4    One place to get started is to try to work out...      None    K    5439
# ..                                                 ...       ...  ...     ...
# 592  Just some musings I thought I’d share…. It occ...      None    K    4620
# 593  I apologize for my naivety, but I must still a...      None    K    4620
# 594  Dear Oinky, (Belated) thanks for your comment....      None    K    4620
# 595  Forex abner grenselose muligheder, giver for a...      None    K    4620
# 596                                   Great writing!!!      None    K    4620
#
#                  id    in-reply-to  \
# 0     P3-K5439-3397            NaN
# 1     P3-K5439-3398            NaN
# 2    P3-Kr5439-3428  P3-K5439-3398
# 3     P3-K5439-3399            NaN
# 4     P3-K5439-3401            NaN
# ..              ...            ...
# 592   P3-K4620-1996            NaN
# 593   P3-K4620-2048            NaN
# 594   P3-K4620-2056            NaN
# 595   P3-K4620-3320            NaN
# 596   P3-K4620-5535            NaN
#
#                                       in-reply-to-href project-id
# 0                                                 None         P3
# 1                                                 None         P3
# 2    https://gilkalai.wordpress.com/2010/09/29/poly...         P3
# 3                                                 None         P3
# 4                                                 None         P3
# ..                                                 ...        ...
# 592                                               None         P3
# 593                                               None         P3
# 594                                               None         P3
# 595                                               None         P3
# 596                                               None         P3
#
# [597 rows x 13 columns]

# %%
# Check: Kalai nested replies
# df_poly3[df_poly3['in-reply-to'] == 'K5439-3430']

# %%
# Check: Kalai LaTeX parsing
df_poly3[df_poly3['comment-id'] == '3403']['content'].iloc[0]
# Out:
# "More generally, one might like to play with the restricted function f'(n), defined as with f(n) except that each of the F_i are forced to be singleton families (i.e. they consist of just one set F_i = A_i, with the $A_1,\\ldots,A_t$ distinct). The condition (*) then becomes that $A_i \\cap A_k \\subset A_j$ whenever $i < j < k$ . It should be possible to compute f'(n) quite precisely. Unfortunately this does not upper bound f(n) since $f'(n) \\leq f(n)$ , but it may offer some intuition."

# %%
download_df(df_poly3, 'polymath3.json')

# %% [markdown]
# ## Polymath4

# %%
poly4_urls = """
https://polymathprojects.org/2009/07/27/proposal-deterministic-way-to-find-primes/
https://polymathprojects.org/2009/07/27/proposal-deterministic-way-to-find-primes/
https://polymathprojects.org/2009/08/13/research-thread-iii-determinstic-way-to-find-primes/
https://polymathprojects.org/2009/08/28/research-thread-iv-determinstic-way-to-find-primes/
https://polymathprojects.org/2009/10/27/research-thread-v-determinstic-way-to-find-primes/
https://polymathprojects.org/2010/06/29/draft-version-of-polymath4-paper/
https://polymathprojects.org/2009/07/28/deterministic-way-to-find-primes-discussion-thread/
https://polymathprojects.org/2010/06/29/draft-version-of-polymath4-paper/
"""
poly4_thread_list = parse_urls(poly4_urls)
poly4_thread_list
# Out:
# [('P',
#   'https://polymathprojects.org/2009/07/27/proposal-deterministic-way-to-find-primes/'),
#  ('P',
#   'https://polymathprojects.org/2009/07/27/proposal-deterministic-way-to-find-primes/'),
#  ('P',
#   'https://polymathprojects.org/2009/08/13/research-thread-iii-determinstic-way-to-find-primes/'),
#  ('P',
#   'https://polymathprojects.org/2009/08/28/research-thread-iv-determinstic-way-to-find-primes/'),
#  ('P',
#   'https://polymathprojects.org/2009/10/27/research-thread-v-determinstic-way-to-find-primes/'),
#  ('P',
#   'https://polymathprojects.org/2010/06/29/draft-version-of-polymath4-paper/'),
#  ('P',
#   'https://polymathprojects.org/2009/07/28/deterministic-way-to-find-primes-discussion-thread/'),
#  ('P',
#   'https://polymathprojects.org/2010/06/29/draft-version-of-polymath4-paper/')]

# %%
df_poly4 = scrape_project(poly4_thread_list)
df_poly4 = configure_columns('P4', df_poly4)
df_poly4
# Out:
#              author                       author-href                time  \
# 0            gowers       http://gowers.wordpress.com 2009-07-27 13:47:00
# 1       Terence Tao     http://www.math.ucla.edu/~tao 2009-07-27 14:47:00
# 2            gowers       http://gowers.wordpress.com 2009-07-27 15:52:00
# 3       Terence Tao     http://www.math.ucla.edu/~tao 2009-07-27 17:04:00
# 4            gowers       http://gowers.wordpress.com 2009-07-27 18:39:00
# ..              ...                               ...                 ...
# 590     Terence Tao     http://www.math.ucla.edu/~tao 2010-09-22 03:21:00
# 591    Girish Varma  http://girishvarma.wordpress.com 2010-11-18 16:39:00
# 592       Anonymous                              None 2011-12-23 08:37:00
# 593  Warren D Smith            http://rangevoting.org 2012-03-23 23:58:00
# 594       Anonymous                              None 2024-05-29 08:03:00
#
#                                           comment-href comment-id  \
# 0    https://polymathprojects.org/2009/07/27/propos...          7
# 1    https://polymathprojects.org/2009/07/27/propos...          8
# 2    https://polymathprojects.org/2009/07/27/propos...         11
# 3    https://polymathprojects.org/2009/07/27/propos...         14
# 4    https://polymathprojects.org/2009/07/27/propos...         25
# ..                                                 ...        ...
# 590  https://polymathprojects.org/2010/06/29/draft-...       2396
# 591  https://polymathprojects.org/2010/06/29/draft-...       2431
# 592  https://polymathprojects.org/2010/06/29/draft-...       4528
# 593  https://polymathprojects.org/2010/06/29/draft-...       5325
# 594  https://polymathprojects.org/2010/06/29/draft-...     196566
#
#                                                content  \
# 0    This is certainly an interesting problem, from...
# 1    Dear Tim, Actually I’ve only thought about thi...
# 2    Amusingly, the problem occurred to me too when...
# 3    I haven’t thought about the problem too deeply...
# 4    I’d be slightly (but possibly wrongly) surpris...
# ..                                                 ...
# 590  The paper is now on the arXiv at http://arxiv....
# 591  I wanted to the answer to a slightly different...
# 592  Hello. Is this wonderfully number theoretic th...
# 593  Hello, I was reading http://arxiv.org/pdf/1009...
# 594  Such an insightful read! Your blog consistentl...
#
#                     child-ids blog post-id              id   in-reply-to  \
# 0                         [8]    P      26        P4-P26-7           NaN
# 1                        None    P      26       P4-Pr26-8      P4-P26-7
# 2    [14, 25, 38, 40, 42, 46]    P      26       P4-P26-11           NaN
# 3                        None    P      26      P4-Pr26-14     P4-P26-11
# 4            [38, 40, 42, 46]    P      26      P4-Pr26-25     P4-P26-11
# ..                        ...  ...     ...             ...           ...
# 590                      None    P     167   P4-Pr167-2396  P4-P167-2395
# 591                      None    P     167    P4-P167-2431           NaN
# 592                      None    P     167    P4-P167-4528           NaN
# 593                      None    P     167    P4-P167-5325           NaN
# 594                      None    P     167  P4-P167-196566           NaN
#
#                                       in-reply-to-href project-id
# 0                                                 None         P4
# 1    https://polymathprojects.org/2009/07/27/propos...         P4
# 2                                                 None         P4
# 3    https://polymathprojects.org/2009/07/27/propos...         P4
# 4    https://polymathprojects.org/2009/07/27/propos...         P4
# ..                                                 ...        ...
# 590  https://polymathprojects.org/2010/06/29/draft-...         P4
# 591                                               None         P4
# 592                                               None         P4
# 593                                               None         P4
# 594                                               None         P4
#
# [595 rows x 13 columns]

# %%
download_df(df_poly4, 'polymath4.json')

# %% [markdown]
# ## Polymath5

# %%
poly5_urls = """
https://gowers.wordpress.com/2009/12/17/erdoss-discrepancy-problem/
https://gowers.wordpress.com/2010/01/06/erdss-discrepancy-problem-as-a-forthcoming-polymath-project/
https://gowers.wordpress.com/2010/01/09/erds-discrepancy-problem-continued/
https://gowers.wordpress.com/2010/01/11/the-erds-discrepancy-problem-iii/
https://gowers.wordpress.com/2010/01/14/the-erds-discrepancy-problem-iv/
https://gowers.wordpress.com/2010/01/16/the-erds-discrepancy-problem-v/
https://gowers.wordpress.com/2010/01/19/edp1-the-official-start-of-polymath5/
https://gowers.wordpress.com/2010/01/21/edp2-a-few-lessons-from-edp1/
https://gowers.wordpress.com/2010/01/26/edp3-a-very-brief-report-on-where-we-are/
https://gowers.wordpress.com/2010/01/30/edp4-focusing-on-multiplicative-functions/
https://gowers.wordpress.com/2010/02/02/edp5-another-very-brief-summary/
https://gowers.wordpress.com/2010/02/05/edp6-what-are-the-chances-of-success/
https://gowers.wordpress.com/2010/02/08/edp7-emergency-post/
https://gowers.wordpress.com/2010/02/19/edp8-what-next/
https://gowers.wordpress.com/2010/02/24/edp9-a-change-of-focus/
https://gowers.wordpress.com/2010/03/02/edp10-a-new-and-very-promising-approach/
https://gowers.wordpress.com/2010/03/07/edp11-the-search-continues/
https://gowers.wordpress.com/2010/03/13/edp12-representing-diagonal-maps/
https://gowers.wordpress.com/2010/03/23/edp13-quick-summary/
https://gowers.wordpress.com/2010/04/25/edp14-strategic-questions/
https://gowers.wordpress.com/2010/06/21/edp15-finding-a-diagonal-matrix/
https://gowers.wordpress.com/2010/07/04/edp16-from-ap-discrepancy-to-hap-discrepancy/
https://gowers.wordpress.com/2010/07/18/edp17-are-we-nearly-there/
https://gowers.wordpress.com/2010/09/03/edp18-apparently-p-does-not-equal-np/
https://gowers.wordpress.com/2010/09/06/edp19-removing-some-vagueness/
https://gowers.wordpress.com/2010/09/10/edp20-squares-and-fly-traps/
https://gowers.wordpress.com/2010/09/21/edp21-restrictions-on-possible-proofs/
https://gowers.wordpress.com/2012/08/27/edp23-second-guest-post-by-gil-kalai/
https://gowers.wordpress.com/2012/08/31/edp24-an-attempt-to-get-back-into-the-diagonal-decomposition-approach/
https://gowers.wordpress.com/2012/09/04/edp25-third-guest-post-by-gil-kalai/
https://gowers.wordpress.com/2012/09/06/edp26-three-generalizations/
https://gowers.wordpress.com/2012/09/19/edp27-the-modular-version-of-roths-ap-discrepancy-theorem/
"""
poly5_thread_list = parse_urls(poly5_urls)
poly5_thread_list
# Out:
# [('G', 'https://gowers.wordpress.com/2009/12/17/erdoss-discrepancy-problem/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/01/06/erdss-discrepancy-problem-as-a-forthcoming-polymath-project/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/01/09/erds-discrepancy-problem-continued/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/01/11/the-erds-discrepancy-problem-iii/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/01/14/the-erds-discrepancy-problem-iv/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/01/16/the-erds-discrepancy-problem-v/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/01/19/edp1-the-official-start-of-polymath5/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/01/21/edp2-a-few-lessons-from-edp1/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/01/26/edp3-a-very-brief-report-on-where-we-are/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/01/30/edp4-focusing-on-multiplicative-functions/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/02/02/edp5-another-very-brief-summary/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/02/05/edp6-what-are-the-chances-of-success/'),
#  ('G', 'https://gowers.wordpress.com/2010/02/08/edp7-emergency-post/'),
#  ('G', 'https://gowers.wordpress.com/2010/02/19/edp8-what-next/'),
#  ('G', 'https://gowers.wordpress.com/2010/02/24/edp9-a-change-of-focus/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/03/02/edp10-a-new-and-very-promising-approach/'),
#  ('G', 'https://gowers.wordpress.com/2010/03/07/edp11-the-search-continues/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/03/13/edp12-representing-diagonal-maps/'),
#  ('G', 'https://gowers.wordpress.com/2010/03/23/edp13-quick-summary/'),
#  ('G', 'https://gowers.wordpress.com/2010/04/25/edp14-strategic-questions/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/06/21/edp15-finding-a-diagonal-matrix/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/07/04/edp16-from-ap-discrepancy-to-hap-discrepancy/'),
#  ('G', 'https://gowers.wordpress.com/2010/07/18/edp17-are-we-nearly-there/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/09/03/edp18-apparently-p-does-not-equal-np/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/09/06/edp19-removing-some-vagueness/'),
#  ('G', 'https://gowers.wordpress.com/2010/09/10/edp20-squares-and-fly-traps/'),
#  ('G',
#   'https://gowers.wordpress.com/2010/09/21/edp21-restrictions-on-possible-proofs/'),
#  ('G',
#   'https://gowers.wordpress.com/2012/08/27/edp23-second-guest-post-by-gil-kalai/'),
#  ('G',
#   'https://gowers.wordpress.com/2012/08/31/edp24-an-attempt-to-get-back-into-the-diagonal-decomposition-approach/'),
#  ('G',
#   'https://gowers.wordpress.com/2012/09/04/edp25-third-guest-post-by-gil-kalai/'),
#  ('G', 'https://gowers.wordpress.com/2012/09/06/edp26-three-generalizations/'),
#  ('G',
#   'https://gowers.wordpress.com/2012/09/19/edp27-the-modular-version-of-roths-ap-discrepancy-theorem/')]

# %%
df_poly5 = scrape_project(poly5_thread_list)
df_poly5 = configure_columns('P5', df_poly5)
df_poly5
# Out:
#                  author                           author-href  \
# 0           Greg Martin                                  None
# 1                gowers          https://gowers.wordpress.com
# 2      ioannis parissis  http://www.math.ist.utl.pt/~parissis
# 3                gowers          https://gowers.wordpress.com
# 4            Jason Dyer    http://numberwarrior.wordpress.com
# ...                 ...                                   ...
# 2629           A.Czuron                                  None
# 2630  Vedic Mathematics   http://www.mastermindvedicmaths.com
# 2631             Thomas                                  None
# 2632        Terence Tao         http://www.math.ucla.edu/~tao
# 2633             gowers          https://gowers.wordpress.com
#
#                     time                                       comment-href  \
# 0    2009-12-17 14:17:00  https://gowers.wordpress.com/2009/12/17/erdoss...
# 1    2009-12-19 13:46:00  https://gowers.wordpress.com/2009/12/17/erdoss...
# 2    2009-12-17 14:37:00  https://gowers.wordpress.com/2009/12/17/erdoss...
# 3    2009-12-17 18:28:00  https://gowers.wordpress.com/2009/12/17/erdoss...
# 4    2009-12-17 16:25:00  https://gowers.wordpress.com/2009/12/17/erdoss...
# ...                  ...                                                ...
# 2629 2012-12-06 15:47:00  https://gowers.wordpress.com/2012/09/19/edp27-...
# 2630 2012-12-25 06:28:00  https://gowers.wordpress.com/2012/09/19/edp27-...
# 2631 2013-08-20 08:12:00  https://gowers.wordpress.com/2012/09/19/edp27-...
# 2632 2014-02-11 16:35:00  https://gowers.wordpress.com/2012/09/19/edp27-...
# 2633 2014-02-11 19:54:00  https://gowers.wordpress.com/2012/09/19/edp27-...
#
#      comment-id                                            content  \
# 0          4497  A Hungarian-umlaut “o” can be generated from U...
# 1          4529               Many thanks — got it sorted out now.
# 2          4498  This is a very naive question. But: In the ori...
# 3          4503  The difference is that the APs are always of t...
# 4          4499  Constructively, wouldn’t it work to take the C...
# ...         ...                                                ...
# 2629      31689  Does HAP of length 1 are satisfactory? For exa...
# 2630      31877                 Nice solutions is given by author.
# 2631      42086  What happened to the revival? It has been almo...
# 2632      49338  There’s a new paper on the arXiv using SAT sol...
# 2633      49415  I was just in the middle of writing a brief po...
#
#                      child-ids blog post-id               id     in-reply-to  \
# 0                       [4529]    G    1368    P5-G1368-4497             NaN
# 1                         None    G    1368   P5-Gr1368-4529   P5-G1368-4497
# 2                       [4503]    G    1368    P5-G1368-4498             NaN
# 3                         None    G    1368   P5-Gr1368-4503   P5-G1368-4498
# 4     [4500, 4501, 4502, 4504]    G    1368    P5-G1368-4499             NaN
# ...                        ...  ...     ...              ...             ...
# 2629                      None    G    4528   P5-G4528-31689             NaN
# 2630                      None    G    4528   P5-G4528-31877             NaN
# 2631                      None    G    4528   P5-G4528-42086             NaN
# 2632                   [49415]    G    4528   P5-G4528-49338             NaN
# 2633                      None    G    4528  P5-Gr4528-49415  P5-G4528-49338
#
#                                        in-reply-to-href project-id
# 0                                                  None         P5
# 1     https://gowers.wordpress.com/2009/12/17/erdoss...         P5
# 2                                                  None         P5
# 3     https://gowers.wordpress.com/2009/12/17/erdoss...         P5
# 4                                                  None         P5
# ...                                                 ...        ...
# 2629                                               None         P5
# 2630                                               None         P5
# 2631                                               None         P5
# 2632                                               None         P5
# 2633  https://gowers.wordpress.com/2012/09/19/edp27-...         P5
#
# [2634 rows x 13 columns]

# %%
download_df(df_poly5, 'polymath5.json')

# %% [markdown]
# ## Polymath6

# %%
poly6_urls = """
https://polymathprojects.org/2011/02/05/polymath6-improving-the-bounds-for-roths-theorem/
http://gowers.wordpress.com/2011/02/05/polymath6-a-is-to-b-as-c-is-to
"""
poly6_thread_list = parse_urls(poly6_urls)

df_poly6 = scrape_project(poly6_thread_list)
df_poly6 = configure_columns('P6', df_poly6)
df_poly6
# Out:
#             author                       author-href                time  \
# 0           gowers       http://gowers.wordpress.com 2011-02-06 11:00:00
# 1           gowers       http://gowers.wordpress.com 2011-02-06 14:39:00
# 2              Tom                              None 2011-02-06 15:04:00
# 3           gowers       http://gowers.wordpress.com 2011-02-06 15:18:00
# 4        Ben Green                              None 2011-02-06 16:57:00
# 5        Ben Green                              None 2011-02-06 17:02:00
# 6           gowers       http://gowers.wordpress.com 2011-02-06 17:40:00
# 7        Nets Katz                              None 2011-02-07 02:53:00
# 8      Olof Sisask                              None 2011-02-07 06:06:00
# 9        Nets Katz                              None 2011-02-07 06:13:00
# 10   Paul Delhanty                              None 2011-02-07 18:04:00
# 11          gowers       http://gowers.wordpress.com 2011-02-07 19:06:00
# 12   Paul Delhanty                              None 2011-02-08 05:14:00
# 13   Paul Delhanty                              None 2011-02-09 03:40:00
# 14   Paul Delhanty                              None 2011-02-09 06:48:00
# 15          gowers       http://gowers.wordpress.com 2011-02-09 08:01:00
# 16       Anonymous                              None 2024-05-13 13:38:00
# 17           David                              None 2011-02-06 00:28:00
# 18     Sakura-chan                              None 2011-02-06 18:54:00
# 19          gowers      https://gowers.wordpress.com 2011-02-06 23:02:00
# 20       Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2011-02-07 05:52:00
# 21          gowers      https://gowers.wordpress.com 2011-02-07 08:11:00
# 22  Klas Markström   http://abel.math.umu.se/~klasm/ 2011-02-07 20:44:00
# 23        valuevar     http://valuevar.wordpress.com 2011-02-08 15:31:00
# 24          gowers      https://gowers.wordpress.com 2011-02-08 15:52:00
# 25       Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2011-02-13 22:04:00
# 26       Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2011-02-09 22:14:00
# 27          gowers      https://gowers.wordpress.com 2011-02-13 18:26:00
# 28       Anonymous                              None 2011-08-02 18:39:00
# 29     Terence Tao     http://www.math.ucla.edu/~tao 2014-05-23 16:01:00
#
#                                          comment-href comment-id  \
# 0   https://polymathprojects.org/2011/02/05/polyma...       2794
# 1   https://polymathprojects.org/2011/02/05/polyma...       2795
# 2   https://polymathprojects.org/2011/02/05/polyma...       2796
# 3   https://polymathprojects.org/2011/02/05/polyma...       2797
# 4   https://polymathprojects.org/2011/02/05/polyma...       2799
# 5   https://polymathprojects.org/2011/02/05/polyma...       2800
# 6   https://polymathprojects.org/2011/02/05/polyma...       2801
# 7   https://polymathprojects.org/2011/02/05/polyma...       2803
# 8   https://polymathprojects.org/2011/02/05/polyma...       2804
# 9   https://polymathprojects.org/2011/02/05/polyma...       2805
# 10  https://polymathprojects.org/2011/02/05/polyma...       2807
# 11  https://polymathprojects.org/2011/02/05/polyma...       2808
# 12  https://polymathprojects.org/2011/02/05/polyma...       2810
# 13  https://polymathprojects.org/2011/02/05/polyma...       2812
# 14  https://polymathprojects.org/2011/02/05/polyma...       2813
# 15  https://polymathprojects.org/2011/02/05/polyma...       2814
# 16  https://polymathprojects.org/2011/02/05/polyma...     196491
# 17  http://gowers.wordpress.com/2011/02/05/polymat...      10602
# 18  http://gowers.wordpress.com/2011/02/05/polymat...      10604
# 19  http://gowers.wordpress.com/2011/02/05/polymat...      10608
# 20  http://gowers.wordpress.com/2011/02/05/polymat...      10610
# 21  http://gowers.wordpress.com/2011/02/05/polymat...      10611
# 22  http://gowers.wordpress.com/2011/02/05/polymat...      10613
# 23  http://gowers.wordpress.com/2011/02/05/polymat...      10615
# 24  http://gowers.wordpress.com/2011/02/05/polymat...      10616
# 25  http://gowers.wordpress.com/2011/02/05/polymat...      10646
# 26  http://gowers.wordpress.com/2011/02/05/polymat...      10618
# 27  http://gowers.wordpress.com/2011/02/05/polymat...      10644
# 28  http://gowers.wordpress.com/2011/02/05/polymat...      11822
# 29  http://gowers.wordpress.com/2011/02/05/polymat...      92533
#
#                                               content  \
# 0   I have a fairly obvious question, which I thin...
# 1   To be slightly more specific, perhaps instead ...
# 2   One small question which occurs to me from the...
# 3   A somewhat related remark is this. I think the...
# 4   WIth regard to the comments on Bohr sets above...
# 5   In our offline email exchanges I mentioned tha...
# 6   Responding to comment 7: I just want to clarif...
# 7   Hi all, I am interested in the project of gett...
# 8   Hi Nets, I created some sections on the wiki f...
# 9   Olof, Thanks. I’m not very experienced with wi...
# 10  I would like to join this project. Unfortunate...
# 11  Could I ask what the difference is between $\m...
# 12  Regarding your very reasonable question, you a...
# 13  This comment is a reply to comment 2 and the n...
# 14  Because the required bound on ${\mathop{\mathb...
# 15  The problem with using the $U_2$ norm (which w...
# 16  Such an insightful read! Your blog consistentl...
# 17  I can only commend everyone’s spirit of cooper...
# 18  What happened to the EDP? It just sort of grad...
# 19  It just sort of gradually wound down as the pa...
# 20  Maybe we should have a reunion EDP post a few ...
# 21       Something like that would suit me very well.
# 22  It is still an interesting problem, but for me...
# 23  Do you think it would be useful to have polyma...
# 24  That’s an important point that we’ve discussed...
# 25  It seems that it will not be realistic to hope...
# 26  Bateman and Katz’s improvement on the cap set ...
# 27  Over on the Polymath blog I have put a new pos...
# 28  Sorry to leave you a comment unrelated to this...
# 29  It looks like Thomas Bloom has now achieved so...
#
#                        child-ids blog post-id               id  \
# 0                           None    P     193     P6-P193-2794
# 1                           None    P     193     P6-P193-2795
# 2                           None    P     193     P6-P193-2796
# 3                           None    P     193     P6-P193-2797
# 4                           None    P     193     P6-P193-2799
# 5                           None    P     193     P6-P193-2800
# 6                           None    P     193     P6-P193-2801
# 7                   [2804, 2805]    P     193     P6-P193-2803
# 8                         [2805]    P     193    P6-Pr193-2804
# 9                           None    P     193    P6-Pr193-2805
# 10                  [2808, 2810]    P     193     P6-P193-2807
# 11                        [2810]    P     193    P6-Pr193-2808
# 12                          None    P     193    P6-Pr193-2810
# 13                  [2813, 2814]    P     193     P6-P193-2812
# 14                          None    P     193    P6-Pr193-2813
# 15                          None    P     193    P6-Pr193-2814
# 16                          None    P     193   P6-P193-196491
# 17                          None    G    2429   P6-G2429-10602
# 18  [10608, 10610, 10611, 10613]    G    2429   P6-G2429-10604
# 19                          None    G    2429  P6-Gr2429-10608
# 20                          None    G    2429  P6-Gr2429-10610
# 21                          None    G    2429  P6-Gr2429-10611
# 22                          None    G    2429  P6-Gr2429-10613
# 23                [10616, 10646]    G    2429   P6-G2429-10615
# 24                          None    G    2429  P6-Gr2429-10616
# 25                          None    G    2429  P6-Gr2429-10646
# 26                          None    G    2429   P6-G2429-10618
# 27                          None    G    2429   P6-G2429-10644
# 28                          None    G    2429   P6-G2429-11822
# 29                          None    G    2429   P6-G2429-92533
#
#        in-reply-to                                   in-reply-to-href  \
# 0              NaN                                               None
# 1              NaN                                               None
# 2              NaN                                               None
# 3              NaN                                               None
# 4              NaN                                               None
# 5              NaN                                               None
# 6              NaN                                               None
# 7              NaN                                               None
# 8     P6-P193-2803  https://polymathprojects.org/2011/02/05/polyma...
# 9     P6-P193-2804  https://polymathprojects.org/2011/02/05/polyma...
# 10             NaN                                               None
# 11    P6-P193-2807  https://polymathprojects.org/2011/02/05/polyma...
# 12    P6-P193-2808  https://polymathprojects.org/2011/02/05/polyma...
# 13             NaN                                               None
# 14    P6-P193-2812  https://polymathprojects.org/2011/02/05/polyma...
# 15    P6-P193-2812  https://polymathprojects.org/2011/02/05/polyma...
# 16             NaN                                               None
# 17             NaN                                               None
# 18             NaN                                               None
# 19  P6-G2429-10604  http://gowers.wordpress.com/2011/02/05/polymat...
# 20  P6-G2429-10604  http://gowers.wordpress.com/2011/02/05/polymat...
# 21  P6-G2429-10604  http://gowers.wordpress.com/2011/02/05/polymat...
# 22  P6-G2429-10604  http://gowers.wordpress.com/2011/02/05/polymat...
# 23             NaN                                               None
# 24  P6-G2429-10615  http://gowers.wordpress.com/2011/02/05/polymat...
# 25  P6-G2429-10615  http://gowers.wordpress.com/2011/02/05/polymat...
# 26             NaN                                               None
# 27             NaN                                               None
# 28             NaN                                               None
# 29             NaN                                               None
#
#    project-id
# 0          P6
# 1          P6
# 2          P6
# 3          P6
# 4          P6
# 5          P6
# 6          P6
# 7          P6
# 8          P6
# 9          P6
# 10         P6
# 11         P6
# 12         P6
# 13         P6
# 14         P6
# 15         P6
# 16         P6
# 17         P6
# 18         P6
# 19         P6
# 20         P6
# 21         P6
# 22         P6
# 23         P6
# 24         P6
# 25         P6
# 26         P6
# 27         P6
# 28         P6
# 29         P6

# %%
download_df(df_poly6, 'polymath6.json')

# %% [markdown]
# ## Polymath7

# %%
poly7_urls = """
http://polymathprojects.org/2012/06/03/polymath-proposal-the-hot-spots-conjecture-for-acute-triangles
http://polymathprojects.org/2012/06/12/polymath7-research-thread-1-the-hot-spots-conjecture/
http://polymathprojects.org/2012/06/15/polymath7-research-threads-2-the-hot-spots-conjecture/
http://polymathprojects.org/2012/06/24/polymath7-research-threads-3-the-hot-spots-conjecture/
http://polymathprojects.org/2012/09/10/polymath7-research-threads-4-the-hot-spots-conjecture
http://polymathprojects.org/2013/08/09/polymath7-research-thread-5-the-hot-spots-conjecture/
https://polymathprojects.org/2012/06/09/polymath7-discussion-thread/
"""
poly7_thread_list = parse_urls(poly7_urls)

df_poly7 = scrape_project(poly7_thread_list)
df_poly7 = configure_columns('P7', df_poly7)
df_poly7
# Out:
#               author                          author-href                time  \
# 0        Terence Tao        http://www.math.ucla.edu/~tao 2012-06-03 03:09:00
# 1    Stuart Anderson              http://www.squaring.net 2012-06-05 08:42:00
# 2     meditationatae  http://meditationatae.wordpress.com 2012-06-05 12:06:00
# 3        Terence Tao        http://www.math.ucla.edu/~tao 2012-06-10 03:39:00
# 4     meditationatae  http://meditationatae.wordpress.com 2012-06-10 07:54:00
# ..               ...                                  ...                 ...
# 527      nilimanigam      http://gravatar.com/nilimanigam 2012-07-21 04:44:00
# 528      Terence Tao        http://www.math.ucla.edu/~tao 2012-08-09 03:07:00
# 529      nilimanigam      http://gravatar.com/nilimanigam 2012-08-09 04:30:00
# 530      Chris Evans    http://gravatar.com/letmeitellyou 2012-09-12 09:18:00
# 531      nilimanigam     http://nilimanigam.wordpress.com 2012-09-12 16:54:00
#
#                                           comment-href comment-id  \
# 0    http://polymathprojects.org/2012/06/03/polymat...       5855
# 1    http://polymathprojects.org/2012/06/03/polymat...       5907
# 2    http://polymathprojects.org/2012/06/03/polymat...       5911
# 3    http://polymathprojects.org/2012/06/03/polymat...       6008
# 4    http://polymathprojects.org/2012/06/03/polymat...       6013
# ..                                                 ...        ...
# 527  https://polymathprojects.org/2012/06/09/polyma...       8098
# 528  https://polymathprojects.org/2012/06/09/polyma...       8877
# 529  https://polymathprojects.org/2012/06/09/polyma...       8882
# 530  https://polymathprojects.org/2012/06/09/polyma...       9853
# 531  https://polymathprojects.org/2012/06/09/polyma...       9865
#
#                                                content  \
# 0    Some initial questions to get the ball rolling...
# 1    Brian J. McCartin has recently published a boo...
# 2    In reply to Stuart Anderson: Brian J. McCartin...
# 3    I worked out the second eigenspace for the equ...
# 4    I’m trying to understand how to verify the con...
# ..                                                 ...
# 527  I’ve posted something twice on the research th...
# 528  Just a short note to say that I’m still intere...
# 529  Apologies about the delay from my end- I’ve be...
# 530  I just wanted to say that Bartlomiej and I are...
# 531         Nice! An analytic approach would be great.
#
#                           child-ids blog post-id             id   in-reply-to  \
# 0    [5907, 5911, 6008, 6013, 6023]    P     266   P7-P266-5855           NaN
# 1          [5911, 6008, 6013, 6023]    P     266  P7-Pr266-5907  P7-P266-5855
# 2                [6008, 6013, 6023]    P     266  P7-Pr266-5911  P7-P266-5907
# 3                      [6013, 6023]    P     266  P7-Pr266-6008  P7-P266-5911
# 4                            [6023]    P     266  P7-Pr266-6013  P7-P266-6008
# ..                              ...  ...     ...            ...           ...
# 527                            None    P     268   P7-P268-8098           NaN
# 528                          [8882]    P     268   P7-P268-8877           NaN
# 529                            None    P     268  P7-Pr268-8882  P7-P268-8877
# 530                          [9865]    P     268   P7-P268-9853           NaN
# 531                            None    P     268  P7-Pr268-9865  P7-P268-9853
#
#                                       in-reply-to-href project-id
# 0                                                 None         P7
# 1    http://polymathprojects.org/2012/06/03/polymat...         P7
# 2    http://polymathprojects.org/2012/06/03/polymat...         P7
# 3    http://polymathprojects.org/2012/06/03/polymat...         P7
# 4    http://polymathprojects.org/2012/06/03/polymat...         P7
# ..                                                 ...        ...
# 527                                               None         P7
# 528                                               None         P7
# 529  https://polymathprojects.org/2012/06/09/polyma...         P7
# 530                                               None         P7
# 531  https://polymathprojects.org/2012/06/09/polyma...         P7
#
# [532 rows x 13 columns]

# %%
download_df(df_poly7, 'polymath7.json')

# %% [markdown]
# ## Polymath8

# %%
# Check: Scott Morrison single thread
# df_morrison = scrape_thread('M', 'https://sbseminar.wordpress.com/2013/05/30/i-just-cant-resist-there-are-infinitely-many-pairs-of-primes-at-most-59470640-apart/')
# df_morrison

# %%
poly8_urls = """
https://terrytao.wordpress.com/2013/06/03/the-prime-tuples-conjecture-sieve-theory-and-the-work-of-goldston-pintz-yildirim-motohashi-pintz-and-zhang/
https://terrytao.wordpress.com/2013/06/04/online-reading-seminar-for-zhangs-bounded-gaps-between-primes/
https://terrytao.wordpress.com/2013/06/08/the-elementary-selberg-sieve-and-bounded-prime-gaps/
https://terrytao.wordpress.com/2013/06/10/a-combinatorial-subset-sum-problem-associated-with-bounded-prime-gaps/
https://terrytao.wordpress.com/2013/06/11/further-analysis-of-the-truncated-gpy-sieve/
https://terrytao.wordpress.com/2013/06/12/estimation-of-the-type-i-and-type-ii-sums/
https://terrytao.wordpress.com/2013/06/14/estimation-of-the-type-iii-sums/
https://terrytao.wordpress.com/2013/06/18/a-truncated-elementary-selberg-sieve-of-pintz/
https://terrytao.wordpress.com/2013/06/23/the-distribution-of-primes-in-densely-divisible-moduli/
https://terrytao.wordpress.com/2013/06/30/bounded-gaps-between-primes-polymath8-a-progress-report/
https://terrytao.wordpress.com/2013/07/27/an-improved-type-i-estimate/
https://terrytao.wordpress.com/2013/08/17/polymath8-writing-the-paper/
https://terrytao.wordpress.com/2013/09/02/polymath8-writing-the-paper-ii/
https://terrytao.wordpress.com/2013/09/22/polymath8-writing-the-paper-iii/
https://terrytao.wordpress.com/2013/10/15/polymath8-writing-the-paper-iv/
https://terrytao.wordpress.com/2013/11/17/polymath8-writing-the-first-paper-v-and-a-look-ahead/
https://terrytao.wordpress.com/2013/11/19/polymath8b-bounded-intervals-with-many-primes-after-maynard/
https://terrytao.wordpress.com/2013/11/22/polymath8b-ii-optimising-the-variational-problem-and-the-sieve/
https://terrytao.wordpress.com/2013/12/08/polymath8b-iii-numerical-optimisation-of-the-variational-problem-and-a-search-for-new-sieves/
https://terrytao.wordpress.com/2013/12/20/polymath8b-iv-enlarging-the-sieve-support-more-efficient-numerics-and-explicit-asymptotics/
https://terrytao.wordpress.com/2014/01/08/polymath8b-v-stretching-the-sieve-support-further/
https://terrytao.wordpress.com/2014/01/17/polymath8b-vi-a-low-dimensional-variational-problem/
https://terrytao.wordpress.com/2014/01/28/polymath8b-vii-using-the-generalised-elliott-halberstam-hypothesis-to-enlarge-the-sieve-support-yet-further/
https://terrytao.wordpress.com/2014/02/09/polymath8b-viii-time-to-start-writing-up-the-results/
https://terrytao.wordpress.com/2014/02/21/polymath8b-ix-large-quadratic-programs/
https://terrytao.wordpress.com/2014/05/17/polymath-8b-xi-finishing-up-the-paper/
https://sbseminar.wordpress.com/2013/05/30/i-just-cant-resist-there-are-infinitely-many-pairs-of-primes-at-most-59470640-apart/
https://sbseminar.wordpress.com/2013/06/05/more-narrow-admissible-sets/
https://sbseminar.wordpress.com/2013/07/02/the-quest-for-narrow-admissible-tuples/
"""
poly8_thread_list = parse_urls(poly8_urls)
poly8_thread_list
# Out:
# [('T',
#   'https://terrytao.wordpress.com/2013/06/03/the-prime-tuples-conjecture-sieve-theory-and-the-work-of-goldston-pintz-yildirim-motohashi-pintz-and-zhang/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/06/04/online-reading-seminar-for-zhangs-bounded-gaps-between-primes/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/06/08/the-elementary-selberg-sieve-and-bounded-prime-gaps/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/06/10/a-combinatorial-subset-sum-problem-associated-with-bounded-prime-gaps/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/06/11/further-analysis-of-the-truncated-gpy-sieve/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/06/12/estimation-of-the-type-i-and-type-ii-sums/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/06/14/estimation-of-the-type-iii-sums/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/06/18/a-truncated-elementary-selberg-sieve-of-pintz/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/06/23/the-distribution-of-primes-in-densely-divisible-moduli/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/06/30/bounded-gaps-between-primes-polymath8-a-progress-report/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/07/27/an-improved-type-i-estimate/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/08/17/polymath8-writing-the-paper/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/09/02/polymath8-writing-the-paper-ii/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/09/22/polymath8-writing-the-paper-iii/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/10/15/polymath8-writing-the-paper-iv/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/11/17/polymath8-writing-the-first-paper-v-and-a-look-ahead/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/11/19/polymath8b-bounded-intervals-with-many-primes-after-maynard/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/11/22/polymath8b-ii-optimising-the-variational-problem-and-the-sieve/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/12/08/polymath8b-iii-numerical-optimisation-of-the-variational-problem-and-a-search-for-new-sieves/'),
#  ('T',
#   'https://terrytao.wordpress.com/2013/12/20/polymath8b-iv-enlarging-the-sieve-support-more-efficient-numerics-and-explicit-asymptotics/'),
#  ('T',
#   'https://terrytao.wordpress.com/2014/01/08/polymath8b-v-stretching-the-sieve-support-further/'),
#  ('T',
#   'https://terrytao.wordpress.com/2014/01/17/polymath8b-vi-a-low-dimensional-variational-problem/'),
#  ('T',
#   'https://terrytao.wordpress.com/2014/01/28/polymath8b-vii-using-the-generalised-elliott-halberstam-hypothesis-to-enlarge-the-sieve-support-yet-further/'),
#  ('T',
#   'https://terrytao.wordpress.com/2014/02/09/polymath8b-viii-time-to-start-writing-up-the-results/'),
#  ('T',
#   'https://terrytao.wordpress.com/2014/02/21/polymath8b-ix-large-quadratic-programs/'),
#  ('T',
#   'https://terrytao.wordpress.com/2014/05/17/polymath-8b-xi-finishing-up-the-paper/'),
#  ('M',
#   'https://sbseminar.wordpress.com/2013/05/30/i-just-cant-resist-there-are-infinitely-many-pairs-of-primes-at-most-59470640-apart/'),
#  ('M',
#   'https://sbseminar.wordpress.com/2013/06/05/more-narrow-admissible-sets/'),
#  ('M',
#   'https://sbseminar.wordpress.com/2013/07/02/the-quest-for-narrow-admissible-tuples/')]

# %%
df_poly8 = scrape_project(poly8_thread_list)
df_poly8 = configure_columns('P8', df_poly8)
df_poly8
# Out:
#                  author                                    author-href  \
# 0        Gergely Harcos                  http://www.renyi.hu/~gharcos/
# 1          Stijn Hanson  https://plus.google.com/116601422779638833535
# 2           Terence Tao                  http://www.math.ucla.edu/~tao
# 3          Stijn Hanson  https://plus.google.com/116601422779638833535
# 4           wanglaoxinr                                    http://none
# ...                 ...                                            ...
# 3499  Andrew Sutherland                      http://math.mit.edu/~drew
# 3500    Wouter Castryck                                           None
# 3501  Andrew Sutherland                      http://math.mit.edu/~drew
# 3502  Andrew Sutherland                      http://math.mit.edu/~drew
# 3503  Andrew Sutherland                      http://math.mit.edu/~drew
#
#                     time                                       comment-href  \
# 0    2013-09-12 16:21:00  https://terrytao.wordpress.com/2013/06/03/the-...
# 1    2013-10-04 11:40:00  https://terrytao.wordpress.com/2013/06/03/the-...
# 2    2013-10-04 12:14:00  https://terrytao.wordpress.com/2013/06/03/the-...
# 3    2013-10-04 12:43:00  https://terrytao.wordpress.com/2013/06/03/the-...
# 4    2015-05-16 00:13:00  https://terrytao.wordpress.com/2013/06/03/the-...
# ...                  ...                                                ...
# 3499 2013-09-03 01:19:00  https://sbseminar.wordpress.com/2013/07/02/the...
# 3500 2013-09-03 05:57:00  https://sbseminar.wordpress.com/2013/07/02/the...
# 3501 2013-09-03 06:24:00  https://sbseminar.wordpress.com/2013/07/02/the...
# 3502 2013-09-03 06:55:00  https://sbseminar.wordpress.com/2013/07/02/the...
# 3503 2013-09-06 04:10:00  https://sbseminar.wordpress.com/2013/07/02/the...
#
#      comment-id                                            content  \
# 0        244903  In the second display below (12), $\frac{n}{d}...
# 1        247234  My apologies for all the help I’m requiring bu...
# 2        247235  One cannot conclude $|F(w(x),x)| \leq \frac{2}...
# 3        247237  I assumed it had something to do with that w r...
# 4        455907  for Cramér Conjecture ，change Pn to x, will th...
# ...         ...                                                ...
# 3499      24537  @Wouter: for k0=6329 and p_exh=17 I get the in...
# 3500      24538  Hi, my slowish implementation is still running...
# 3501      24539  I think it probably makes sense to go with the...
# 3502      24540  Regarding #38, I realized my implementation wa...
# 3503      24548  Just to follow up on #41 and #42, it looks lik...
#
#              child-ids blog post-id                id      in-reply-to  \
# 0     [247235, 247237]    T    6728   P8-T6728-244903              NaN
# 1     [247235, 247237]    T    6728   P8-T6728-247234              NaN
# 2             [247237]    T    6728  P8-Tr6728-247235  P8-T6728-247234
# 3                 None    T    6728  P8-Tr6728-247237  P8-T6728-247235
# 4             [461131]    T    6728   P8-T6728-455907              NaN
# ...                ...  ...     ...               ...              ...
# 3499              None    M    5146    P8-M5146-24537              NaN
# 3500              None    M    5146    P8-M5146-24538              NaN
# 3501              None    M    5146    P8-M5146-24539              NaN
# 3502              None    M    5146    P8-M5146-24540              NaN
# 3503              None    M    5146    P8-M5146-24548              NaN
#
#                                        in-reply-to-href project-id
# 0                                                  None         P8
# 1                                                  None         P8
# 2     https://terrytao.wordpress.com/2013/06/03/the-...         P8
# 3     https://terrytao.wordpress.com/2013/06/03/the-...         P8
# 4                                                  None         P8
# ...                                                 ...        ...
# 3499                                               None         P8
# 3500                                               None         P8
# 3501                                               None         P8
# 3502                                               None         P8
# 3503                                               None         P8
#
# [3504 rows x 13 columns]

# %%
download_df(df_poly8, 'polymath8.json')

# %% [markdown]
# ## Polymath9

# %%
poly9_urls = """
https://gowers.wordpress.com/2013/10/24/what-i-did-in-my-summer-holidays/
https://gowers.wordpress.com/2013/11/03/dbd1-initial-post/
https://gowers.wordpress.com/2014/01/09/dbd2-success-of-a-kind/
"""
poly9_thread_list = parse_urls(poly9_urls)

df_poly9 = scrape_project(poly9_thread_list)
df_poly9 = configure_columns('P9', df_poly9)
df_poly9
# Out:
#              author                          author-href                time  \
# 0    meditationatae  http://meditationatae.wordpress.com 2013-10-24 19:36:00
# 1            gowers         https://gowers.wordpress.com 2013-10-25 16:06:00
# 2        E.L. Wisty                                 None 2013-10-25 14:05:00
# 3     Richard Elwes        http://www.richardelwes.co.uk 2013-10-25 15:30:00
# 4    meditationatae  http://meditationatae.wordpress.com 2013-10-25 20:41:00
# ..              ...                                  ...                 ...
# 100          vznvzn            http://vzn1.wordpress.com 2014-01-11 16:53:00
# 101          gowers         https://gowers.wordpress.com 2014-01-12 16:44:00
# 102      Jason Dyer   http://numberwarrior.wordpress.com 2014-02-27 19:12:00
# 103      Jason Dyer   http://numberwarrior.wordpress.com 2014-02-27 19:30:00
# 104      Jason Dyer   http://numberwarrior.wordpress.com 2014-02-28 15:16:00
#
#                                           comment-href comment-id  \
# 0    https://gowers.wordpress.com/2013/10/24/what-i...      43602
# 1    https://gowers.wordpress.com/2013/10/24/what-i...      43616
# 2    https://gowers.wordpress.com/2013/10/24/what-i...      43614
# 3    https://gowers.wordpress.com/2013/10/24/what-i...      43615
# 4    https://gowers.wordpress.com/2013/10/24/what-i...      43621
# ..                                                 ...        ...
# 100  https://gowers.wordpress.com/2014/01/09/dbd2-s...      45245
# 101  https://gowers.wordpress.com/2014/01/09/dbd2-s...      45293
# 102  https://gowers.wordpress.com/2014/01/09/dbd2-s...      53616
# 103  https://gowers.wordpress.com/2014/01/09/dbd2-s...      53621
# 104  https://gowers.wordpress.com/2014/01/09/dbd2-s...      53842
#
#                                                content child-ids blog post-id  \
# 0    I have been really intrigued by P=?NP : “How c...   [43616]    G    5141
# 1                         I have no objection to that.      None    G    5141
# 2    Reblogged this on Pink Iguana and commented: L...      None    G    5141
# 3    If this project results in an interesting theo...      None    G    5141
# 4                   Reblogged this on meditationatae .      None    G    5141
# ..                                                 ...       ...  ...     ...
# 100  bummer, yet still progress. it is better to ha...      None    G    5256
# 101  Pavel has just emailed me with a further obser...   [53616]    G    5256
# 102  Did this move to email collaboration? As far m...      None    G    5256
# 103  If you open up to “either player can move on a...   [53842]    G    5256
# 104  Subsidiary query: most games encompass PSPACE-...      None    G    5256
#
#                   id     in-reply-to  \
# 0     P9-G5141-43602             NaN
# 1    P9-Gr5141-43616  P9-G5141-43602
# 2     P9-G5141-43614             NaN
# 3     P9-G5141-43615             NaN
# 4     P9-G5141-43621             NaN
# ..               ...             ...
# 100   P9-G5256-45245             NaN
# 101   P9-G5256-45293             NaN
# 102  P9-Gr5256-53616  P9-G5256-45293
# 103   P9-G5256-53621             NaN
# 104  P9-Gr5256-53842  P9-G5256-53621
#
#                                       in-reply-to-href project-id
# 0                                                 None         P9
# 1    https://gowers.wordpress.com/2013/10/24/what-i...         P9
# 2                                                 None         P9
# 3                                                 None         P9
# 4                                                 None         P9
# ..                                                 ...        ...
# 100                                               None         P9
# 101                                               None         P9
# 102  https://gowers.wordpress.com/2014/01/09/dbd2-s...         P9
# 103                                               None         P9
# 104  https://gowers.wordpress.com/2014/01/09/dbd2-s...         P9
#
# [105 rows x 13 columns]

# %%
download_df(df_poly9, 'polymath9.json')

# %% [markdown]
# ## Polymath10

# %%
poly10_urls = """
https://gilkalai.wordpress.com/2015/11/03/polymath10-the-erdos-rado-delta-system-conjecture/
https://gilkalai.wordpress.com/2015/11/11/polymath10-post-2-homological-approach/
https://gilkalai.wordpress.com/2015/12/08/polymath-10-post-3-how-are-we-doing/
https://gilkalai.wordpress.com/2016/01/31/polymath10-post-4-back-to-the-drawing-board/
"""
poly10_thread_list = parse_urls(poly10_urls)

df_poly10 = scrape_project(poly10_thread_list)
df_poly10 = configure_columns('P10', df_poly10)
df_poly10
# Out:
#                  author                       author-href                time  \
# 0         shacharlovett                              None 2015-11-03 05:42:00
# 1             Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2015-11-03 12:25:00
# 2                gowers       http://gowers.wordpress.com 2015-11-03 14:16:00
# 3                gowers       http://gowers.wordpress.com 2015-11-03 14:37:00
# 4             Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2015-11-03 15:41:00
# ..                  ...                               ...                 ...
# 356           Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2016-02-18 07:10:00
# 357            domotorp        http://www.cs.elte.hu/~dom 2016-02-18 16:43:00
# 358  Ferdinand Ihringer          http://math.ihringer.org 2016-02-18 20:18:00
# 359  Ferdinand Ihringer          http://math.ihringer.org 2016-02-20 17:19:00
# 360            domotorp        http://www.cs.elte.hu/~dom 2016-05-14 10:41:00
#
#                                           comment-href comment-id  \
# 0    https://gilkalai.wordpress.com/2015/11/03/poly...      22185
# 1    https://gilkalai.wordpress.com/2015/11/03/poly...      22193
# 2    https://gilkalai.wordpress.com/2015/11/03/poly...      22197
# 3    https://gilkalai.wordpress.com/2015/11/03/poly...      22199
# 4    https://gilkalai.wordpress.com/2015/11/03/poly...      22202
# ..                                                 ...        ...
# 356  https://gilkalai.wordpress.com/2016/01/31/poly...      23878
# 357  https://gilkalai.wordpress.com/2016/01/31/poly...      23880
# 358  https://gilkalai.wordpress.com/2016/01/31/poly...      23885
# 359  https://gilkalai.wordpress.com/2016/01/31/poly...      23889
# 360  https://gilkalai.wordpress.com/2016/01/31/poly...      24559
#
#                                                content              child-ids  \
# 0    Hi Gil, I cannot see some of the equations as ...                [22193]
# 1            Dear Shachar, thanks! I fixed it (I hope)                   None
# 2    I hope to leave a more sensible comment soon, ...                   None
# 3    I’ve just looked up what the middle part of a ...                [22202]
# 4    Dear Tim, I think that Erdos-Ko-Rado theory is...                   None
# ..                                                 ...                    ...
# 356  Since we did not have comments for a while let...  [23880, 23885, 23889]
# 357  Great to know. I would be very interested in s...         [23885, 23889]
# 358  I would be very interested as well. Some thing...                   None
# 359  Now that I am going through my write-up yet an...                   None
# 360                                Bounds for cap sets                   None
#
#     blog post-id                 id       in-reply-to  \
# 0      K   13306   P10-K13306-22185               NaN
# 1      K   13306  P10-Kr13306-22193  P10-K13306-22185
# 2      K   13306   P10-K13306-22197               NaN
# 3      K   13306   P10-K13306-22199               NaN
# 4      K   13306  P10-Kr13306-22202  P10-K13306-22199
# ..   ...     ...                ...               ...
# 356    K   13447   P10-K13447-23878               NaN
# 357    K   13447  P10-Kr13447-23880  P10-K13447-23878
# 358    K   13447  P10-Kr13447-23885  P10-K13447-23880
# 359    K   13447  P10-Kr13447-23889  P10-K13447-23880
# 360    K   13447   P10-K13447-24559               NaN
#
#                                       in-reply-to-href project-id
# 0                                                 None        P10
# 1    https://gilkalai.wordpress.com/2015/11/03/poly...        P10
# 2                                                 None        P10
# 3                                                 None        P10
# 4    https://gilkalai.wordpress.com/2015/11/03/poly...        P10
# ..                                                 ...        ...
# 356                                               None        P10
# 357  https://gilkalai.wordpress.com/2016/01/31/poly...        P10
# 358  https://gilkalai.wordpress.com/2016/01/31/poly...        P10
# 359  https://gilkalai.wordpress.com/2016/01/31/poly...        P10
# 360                                               None        P10
#
# [361 rows x 13 columns]

# %%
download_df(df_poly10, 'polymath10.json')

# %% [markdown]
# ## Polymath11

# %%
poly11_urls = """
https://gowers.wordpress.com/2016/01/21/frankls-union-closed-conjecture-a-possible-polymath-project/
https://gowers.wordpress.com/2016/01/29/func1-strengthenings-variants-potential-counterexamples/
https://gowers.wordpress.com/2016/02/08/func2-more-examples/
https://gowers.wordpress.com/2016/02/13/func3-further-strengthenings-and-variants/
https://gowers.wordpress.com/2016/02/22/func4-further-variants/
"""
poly11_thread_list = parse_urls(poly11_urls)

df_poly11 = scrape_project(poly11_thread_list)
df_poly11 = configure_columns('P11', df_poly11)
df_poly11
# Out:
#            author                       author-href                time  \
# 0     David Bevan      http://dibevan.wordpress.com 2016-01-21 13:48:00
# 1          gowers      https://gowers.wordpress.com 2016-01-21 16:51:00
# 2       Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2016-01-21 16:59:00
# 3       Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2016-01-21 19:13:00
# 4       Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2016-01-21 19:17:00
# ..            ...                               ...                 ...
# 675  jean-camille                              None 2018-02-13 04:59:00
# 676  jean-camille                              None 2018-02-13 16:15:00
# 677  jean-camille                              None 2018-02-13 04:01:00
# 678    Roy Abrams                              None 2018-07-05 18:46:00
# 679    Roy Abrams                              None 2018-07-05 18:59:00
#
#                                           comment-href comment-id  \
# 0    https://gowers.wordpress.com/2016/01/21/frankl...     153615
# 1    https://gowers.wordpress.com/2016/01/21/frankl...     153620
# 2    https://gowers.wordpress.com/2016/01/21/frankl...     153622
# 3    https://gowers.wordpress.com/2016/01/21/frankl...     153624
# 4    https://gowers.wordpress.com/2016/01/21/frankl...     153625
# ..                                                 ...        ...
# 675  https://gowers.wordpress.com/2016/02/22/func4-...     256259
# 676  https://gowers.wordpress.com/2016/02/22/func4-...     256361
# 677  https://gowers.wordpress.com/2016/02/22/func4-...     256244
# 678  https://gowers.wordpress.com/2016/02/22/func4-...     321414
# 679  https://gowers.wordpress.com/2016/02/22/func4-...     321417
#
#                                                content child-ids blog post-id  \
# 0    Perhaps a suitable initial step would be to st...  [153620]    G    5979
# 1    I agree that that seems very sensible. Accordi...      None    G    5979
# 2    Cool! let’s see how it goes! I will try to tak...      None    G    5979
# 3    Let me also mention that a MathOverflow questi...      None    G    5979
# 4    And for polymath connoisseurs, I posed a sort ...      None    G    5979
# ..                                                 ...       ...  ...     ...
# 675  I forget a fifth axiom : any member of the “Un...      None    G    6118
# 676  No this fifth axiom is not good at all : I wan...      None    G    6118
# 677  NOT : $t\in \bigcap T$ BUT $t\in \bigcup U$ ot...      None    G    6118
# 678  You can assign numbers to the sets in a union-...  [321417]    G    6118
# 679  The inequality grows exponentially. Frankl’s c...      None    G    6118
#
#                     id       in-reply-to  \
# 0     P11-G5979-153615               NaN
# 1    P11-Gr5979-153620  P11-G5979-153615
# 2     P11-G5979-153622               NaN
# 3     P11-G5979-153624               NaN
# 4     P11-G5979-153625               NaN
# ..                 ...               ...
# 675  P11-Gr6118-256259  P11-G6118-256242
# 676  P11-Gr6118-256361  P11-G6118-256242
# 677   P11-G6118-256244               NaN
# 678   P11-G6118-321414               NaN
# 679  P11-Gr6118-321417  P11-G6118-321414
#
#                                       in-reply-to-href project-id
# 0                                                 None        P11
# 1    https://gowers.wordpress.com/2016/01/21/frankl...        P11
# 2                                                 None        P11
# 3                                                 None        P11
# 4                                                 None        P11
# ..                                                 ...        ...
# 675  https://gowers.wordpress.com/2016/02/22/func4-...        P11
# 676  https://gowers.wordpress.com/2016/02/22/func4-...        P11
# 677                                               None        P11
# 678                                               None        P11
# 679  https://gowers.wordpress.com/2016/02/22/func4-...        P11
#
# [680 rows x 13 columns]

# %%
download_df(df_poly11, 'polymath11.json')

# %% [markdown]
# ## Polymath12

# %%
poly12_urls = """
https://polymathprojects.org/2017/02/23/rotas-basis-conjecture-polymath-12/
https://polymathprojects.org/2017/03/06/rotas-basis-conjecture-polymath-12-2/
https://polymathprojects.org/2017/05/05/rotas-basis-conjecture-polymath-12-post-3/
"""
poly12_thread_list = parse_urls(poly12_urls)

df_poly12 = scrape_project(poly12_thread_list)
df_poly12 = configure_columns('P12', df_poly12)
df_poly12
# Out:
#               author                       author-href                time  \
# 0          Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2017-02-24 05:45:00
# 1    Thomas Sauvaget                              None 2017-02-24 08:22:00
# 2    Thomas Sauvaget                              None 2017-02-24 10:04:00
# 3             tchow8                              None 2017-02-24 16:02:00
# 4    rebeccastones82                              None 2017-02-24 12:54:00
# ..               ...                               ...                 ...
# 212           tchow8                              None 2017-10-23 00:21:00
# 213        Gil Kalai  http://www.ma.huji.ac.il/~kalai/ 2018-10-19 08:49:00
# 214        Anonymous                              None 2024-02-04 18:20:00
# 215        Anonymous                              None 2024-05-19 11:46:00
# 216        Anonymous                              None 2024-05-27 00:24:00
#
#                                           comment-href comment-id  \
# 0    https://polymathprojects.org/2017/02/23/rotas-...     115048
# 1    https://polymathprojects.org/2017/02/23/rotas-...     115050
# 2    https://polymathprojects.org/2017/02/23/rotas-...     115051
# 3    https://polymathprojects.org/2017/02/23/rotas-...     115058
# 4    https://polymathprojects.org/2017/02/23/rotas-...     115052
# ..                                                 ...        ...
# 212  https://polymathprojects.org/2017/05/05/rotas-...     117238
# 213  https://polymathprojects.org/2017/05/05/rotas-...     125369
# 214  https://polymathprojects.org/2017/05/05/rotas-...     196442
# 215  https://polymathprojects.org/2017/05/05/rotas-...     196524
# 216  https://polymathprojects.org/2017/05/05/rotas-...     196564
#
#                                                content  \
# 0    Congratulation, Tim, for launching polymath12....
# 1    This looks interesting! In the spirit of polym...
# 2    The indices I’ve used should be different of c...
# 3                                Yes, this is correct.
# 4    Thanks for organizing this. I’m coming at this...
# ..                                                 ...
# 212  Although Polymath 12 seems to have gone dorman...
# 213  Very nice progress in the paper Halfway to Rot...
# 214  Is there exist a matroid such that all bases h...
# 215
# 216                             Richard Taylor is a Mo
#
#                                              child-ids blog post-id  \
# 0                                                 None    P     484
# 1                                     [115051, 115058]    P     484
# 2                                                 None    P     484
# 3                                                 None    P     484
# 4    [115053, 115054, 115103, 115120, 115123, 11512...    P     484
# ..                                                 ...  ...     ...
# 212                                               None    P     951
# 213                                               None    P     951
# 214                                               None    P     951
# 215                                               None    P     951
# 216                                               None    P     951
#
#                    id      in-reply-to  \
# 0     P12-P484-115048              NaN
# 1     P12-P484-115050              NaN
# 2    P12-Pr484-115051  P12-P484-115050
# 3    P12-Pr484-115058  P12-P484-115050
# 4     P12-P484-115052              NaN
# ..                ...              ...
# 212   P12-P951-117238              NaN
# 213   P12-P951-125369              NaN
# 214   P12-P951-196442              NaN
# 215   P12-P951-196524              NaN
# 216   P12-P951-196564              NaN
#
#                                       in-reply-to-href project-id
# 0                                                 None        P12
# 1                                                 None        P12
# 2    https://polymathprojects.org/2017/02/23/rotas-...        P12
# 3    https://polymathprojects.org/2017/02/23/rotas-...        P12
# 4                                                 None        P12
# ..                                                 ...        ...
# 212                                               None        P12
# 213                                               None        P12
# 214                                               None        P12
# 215                                               None        P12
# 216                                               None        P12
#
# [217 rows x 13 columns]

# %%
# Check: Polymath blog LaTeX parsing
df_poly12[df_poly12['comment-id'] == '115050']['content'].iloc[0]
# Out:
# 'This looks interesting! In the spirit of polymath projects where even tiny comments are allowed, and just to check my understanding, would you agree that the problem can be reformulated as : Show that for any $n\\in \\mathbb{N}*$ the following game has a winning strategy. a) Pick any $n$ bases $B_1:=( b_{1,1},\\cdots ,b_{1,n}),\\cdots ,$ $B_n:=( b_{n,1},\\cdots ,b_{n,n})$ b) Place them along the diagonal of an $n\\times n$ grid : $\\begin{matrix} B_1 & & & \\\\ & B_2 & &\\\\ & & \\ddots & \\\\ & & & B_n\\end{matrix}$ c) move sideways the elements of each $B_i$ to other cells so that only one element remains in each cell d) now for each column of the grid gather all its $n$ vectors : $\\begin{matrix} b_{1,i_1} & \\cdots & \\cdots & b_{1,i_n}\\\\ b_{2,i_1} & \\cdots & \\cdots & b_{2,i_n}\\\\ \\hdots & \\hdots & \\hdots & \\hdots \\\\ b_{n,i_1} & \\cdots & \\cdots & b_{n,i_n}\\\\ \\hline A_1:=(b_{1,i_1}, \\cdots ,b_{n,i_1}) & \\cdots & \\cdots & A_n:= (b_{1,i_n}, \\cdots ,b_{n,i_n}) \\end{matrix}$ e) the game is won if all $n$ sets $A_1, \\cdots , A_n$ are bases'

# %%
download_df(df_poly12, 'polymath12.json')

# %% [markdown]
# ## Polymath13

# %%
poly13_urls = """
https://gowers.wordpress.com/2017/04/28/a-potential-new-polymath-project-intransitive-dice/
https://gowers.wordpress.com/2017/05/12/intransitive-dice-ii/
https://gowers.wordpress.com/2017/05/19/intransitive-dice-iii/
https://gowers.wordpress.com/2017/05/27/intransitive-dice-iv-first-problem-more-or-less-solved/
https://gowers.wordpress.com/2017/05/30/intransitive-dice-v-we-want-a-local-central-limit-theorem/
https://gowers.wordpress.com/2017/07/25/intransitive-dice-vi-sketch-proof-of-the-main-conjecture-for-the-balanced-sequences-model/
https://gowers.wordpress.com/2017/08/12/intransitive-dice-vii-aiming-for-further-results/
"""
poly13_thread_list = parse_urls(poly13_urls)

df_poly13 = scrape_project(poly13_thread_list)
df_poly13 = configure_columns('P13', df_poly13)
df_poly13
# Out:
#              author                   author-href                time  \
# 0      Brian Conrey                          None 2017-04-28 19:45:00
# 1            gowers  https://gowers.wordpress.com 2017-04-28 21:38:00
# 2    Kevin Costello                          None 2017-04-28 21:56:00
# 3            gowers  https://gowers.wordpress.com 2017-04-29 09:56:00
# 4            gowers  https://gowers.wordpress.com 2017-04-29 10:10:00
# ..              ...                           ...                 ...
# 301               K                          None 2018-02-05 10:19:00
# 302          gowers  https://gowers.wordpress.com 2018-02-05 12:38:00
# 303               K                          None 2018-02-09 23:00:00
# 304               K                          None 2018-04-30 20:25:00
# 305          gowers  https://gowers.wordpress.com 2018-05-04 11:44:00
#
#                                           comment-href comment-id  \
# 0    https://gowers.wordpress.com/2017/04/28/a-pote...     168834
# 1    https://gowers.wordpress.com/2017/04/28/a-pote...     168836
# 2    https://gowers.wordpress.com/2017/04/28/a-pote...     168837
# 3    https://gowers.wordpress.com/2017/04/28/a-pote...     168847
# 4    https://gowers.wordpress.com/2017/04/28/a-pote...     168848
# ..                                                 ...        ...
# 301  https://gowers.wordpress.com/2017/08/12/intran...     254336
# 302  https://gowers.wordpress.com/2017/08/12/intran...     254361
# 303  https://gowers.wordpress.com/2017/08/12/intran...     255532
# 304  https://gowers.wordpress.com/2017/08/12/intran...     291413
# 305  https://gowers.wordpress.com/2017/08/12/intran...     292636
#
#                                                content         child-ids blog  \
# 0    Thanks, Tim, for posting this. The only thing ...              None    G
# 1    Continuing the analogy with the angles-between...              None    G
# 2    For the question of “How likely is it that two...  [168847, 168848]    G
# 3    I like this idea. To make a start on it, one c...              None    G
# 4    Also, it looks to me as though the ties questi...              None    G
# ..                                                 ...               ...  ...
# 301  I am very curious – is there some progress in ...  [254361, 255532]    G
# 302  I’ve been so busy on other projects that I hav...              None    G
# 303         Wonderful, I am very much looking forward.              None    G
# 304  In the last few months, did you consider wheth...          [292636]    G
# 305  Apologies, it’s on my to-do list but unfortuna...              None    G
#
#     post-id                 id       in-reply-to  \
# 0      6224   P13-G6224-168834               NaN
# 1      6224   P13-G6224-168836               NaN
# 2      6224   P13-G6224-168837               NaN
# 3      6224  P13-Gr6224-168847  P13-G6224-168837
# 4      6224  P13-Gr6224-168848  P13-G6224-168837
# ..      ...                ...               ...
# 301    6345   P13-G6345-254336               NaN
# 302    6345  P13-Gr6345-254361  P13-G6345-254336
# 303    6345  P13-Gr6345-255532  P13-G6345-254336
# 304    6345   P13-G6345-291413               NaN
# 305    6345  P13-Gr6345-292636  P13-G6345-291413
#
#                                       in-reply-to-href project-id
# 0                                                 None        P13
# 1                                                 None        P13
# 2                                                 None        P13
# 3    https://gowers.wordpress.com/2017/04/28/a-pote...        P13
# 4    https://gowers.wordpress.com/2017/04/28/a-pote...        P13
# ..                                                 ...        ...
# 301                                               None        P13
# 302  https://gowers.wordpress.com/2017/08/12/intran...        P13
# 303  https://gowers.wordpress.com/2017/08/12/intran...        P13
# 304                                               None        P13
# 305  https://gowers.wordpress.com/2017/08/12/intran...        P13
#
# [306 rows x 13 columns]

# %%
download_df(df_poly13, 'polymath13.json')

# %% [markdown]
# ## Polymath14

# %%
poly14_urls = """
https://terrytao.wordpress.com/2017/12/16/bi-invariant-metrics-of-linear-growth-on-the-free-group/
https://terrytao.wordpress.com/2017/12/19/bi-invariant-metrics-of-linear-growth-on-the-free-group-ii/
https://terrytao.wordpress.com/2017/12/21/metrics-of-linear-growth-the-solution/
"""
poly14_thread_list = parse_urls(poly14_urls)

df_poly14 = scrape_project(poly14_thread_list)
df_poly14 = configure_columns('P14', df_poly14)
df_poly14
# Out:
#                author                                        author-href  \
# 0        Tobias Fritz        http://personal-homepages.mis.mpg.de/fritz/
# 1    Alexander Shamov  https://www.facebook.com/app_scoped_user_id/10...
# 2      Lior Silberman                      http://www.math.ubc.ca/~lior/
# 3          Will Sawin                            http://williamsawin.com
# 4      Lior Silberman                      http://www.math.ubc.ca/~lior/
# ..                ...                                                ...
# 331           sgadgil                  http://math.iisc.ernet.in/~gadgil
# 332      Tobias Fritz        http://personal-homepages.mis.mpg.de/fritz/
# 333     Apoorva Khare                 http://www.math.iisc.ac.in/~khare/
# 334    Lior Silberman                     https://www.math.ubc.ca/~lior/
# 335     Apoorva Khare                 http://www.math.iisc.ac.in/~khare/
#
#                    time                                       comment-href  \
# 0   2017-12-16 23:42:00  https://terrytao.wordpress.com/2017/12/16/bi-i...
# 1   2017-12-16 23:52:00  https://terrytao.wordpress.com/2017/12/16/bi-i...
# 2   2017-12-17 00:34:00  https://terrytao.wordpress.com/2017/12/16/bi-i...
# 3   2017-12-17 01:43:00  https://terrytao.wordpress.com/2017/12/16/bi-i...
# 4   2017-12-17 08:33:00  https://terrytao.wordpress.com/2017/12/16/bi-i...
# ..                  ...                                                ...
# 331 2018-01-11 07:08:00  https://terrytao.wordpress.com/2017/12/21/metr...
# 332 2018-01-11 09:10:00  https://terrytao.wordpress.com/2017/12/21/metr...
# 333 2018-01-11 09:09:00  https://terrytao.wordpress.com/2017/12/21/metr...
# 334 2018-01-11 11:32:00  https://terrytao.wordpress.com/2017/12/21/metr...
# 335 2018-01-11 20:01:00  https://terrytao.wordpress.com/2017/12/21/metr...
#
#     comment-id                                            content  \
# 0       490066  As a rather trivial observation, it may be wor...
# 1       490068  > What is not clear to me is if one can keep a...
# 2       490070  Take the direct sum of the representation and ...
# 3       490074  There is no such norm on the Heisenberg group,...
# 4       490099  Great! This shows that every norm on a nilpote...
# ..         ...                                                ...
# 331     491302  I would say yes to GT – the tradition is that ...
# 332     491306                           Sounds great, thank you!
# 333     491305  My apologies for the multiple comments here: I...
# 334     491320  One more typo: in the proof of Thm 4.3, we pul...
# 335     491326  The Polymath14 paper is now up on the arXiv, a...
#
#                             child-ids blog post-id                  id  \
# 0    [490070, 490074, 490099, 490076]    T   10356   P14-T10356-490066
# 1    [490070, 490074, 490099, 490076]    T   10356   P14-T10356-490068
# 2                    [490074, 490099]    T   10356  P14-Tr10356-490070
# 3                            [490099]    T   10356  P14-Tr10356-490074
# 4                                None    T   10356  P14-Tr10356-490099
# ..                                ...  ...     ...                 ...
# 331                              None    T   10369  P14-Tr10369-491302
# 332                              None    T   10369  P14-Tr10369-491306
# 333                          [491320]    T   10369   P14-T10369-491305
# 334                              None    T   10369  P14-Tr10369-491320
# 335                              None    T   10369   P14-T10369-491326
#
#            in-reply-to                                   in-reply-to-href  \
# 0                  NaN                                               None
# 1                  NaN                                               None
# 2    P14-T10356-490068  https://terrytao.wordpress.com/2017/12/16/bi-i...
# 3    P14-T10356-490070  https://terrytao.wordpress.com/2017/12/16/bi-i...
# 4    P14-T10356-490074  https://terrytao.wordpress.com/2017/12/16/bi-i...
# ..                 ...                                                ...
# 331  P14-T10369-491297  https://terrytao.wordpress.com/2017/12/21/metr...
# 332  P14-T10369-491297  https://terrytao.wordpress.com/2017/12/21/metr...
# 333                NaN                                               None
# 334  P14-T10369-491305  https://terrytao.wordpress.com/2017/12/21/metr...
# 335                NaN                                               None
#
#     project-id
# 0          P14
# 1          P14
# 2          P14
# 3          P14
# 4          P14
# ..         ...
# 331        P14
# 332        P14
# 333        P14
# 334        P14
# 335        P14
#
# [336 rows x 13 columns]

# %%
download_df(df_poly14, 'polymath14.json')

# %% [markdown]
# ## Polymath15

# %%
poly15_urls = """
https://terrytao.wordpress.com/2018/01/24/polymath-proposal-upper-bounding-the-de-bruijn-newman-constant/
https://terrytao.wordpress.com/2018/01/27/polymath15-first-thread-computing-h_t-asymptotics-and-dynamics-of-zeroes/
https://terrytao.wordpress.com/2018/02/02/polymath15-second-thread-generalising-the-riemann-siegel-approximate-functional-equation/
https://terrytao.wordpress.com/2018/02/12/polymath15-third-thread-computing-and-approximating-h_t/
https://terrytao.wordpress.com/2018/02/24/polymath15-fourth-thread-closing-in-on-the-test-problem/
https://terrytao.wordpress.com/2018/03/02/polymath15-fifth-thread-finishing-off-the-test-problem/
https://terrytao.wordpress.com/2018/03/18/polymath15-sixth-thread-the-test-problem-and-beyond/
https://terrytao.wordpress.com/2018/03/28/polymath15-seventh-thread-going-below-0-48/
https://terrytao.wordpress.com/2018/04/17/polymath15-eighth-thread-going-below-0-28/
https://terrytao.wordpress.com/2018/05/04/polymath15-ninth-thread-going-below-0-22/
https://terrytao.wordpress.com/2018/09/06/polymath15-tenth-thread-numerics-update/
https://terrytao.wordpress.com/2018/12/28/polymath-15-eleventh-thread-writing-up-the-results-and-exploring-negative-t/
https://terrytao.wordpress.com/2019/04/30/11075/
"""
poly15_thread_list = parse_urls(poly15_urls)

df_poly15 = scrape_project(poly15_thread_list)
df_poly15 = configure_columns('P15', df_poly15)
df_poly15
# Out:
#                author                      author-href                time  \
# 0                Jair                             None 2018-01-24 17:05:00
# 1           Anonymous                             None 2018-01-24 17:44:00
# 2           Anonymous                             None 2018-01-24 20:41:00
# 3           Anonymous                             None 2018-01-25 02:27:00
# 4           Anonymous                             None 2018-01-25 05:46:00
# ...               ...                              ...                 ...
# 1198        Anonymous                             None 2020-04-22 22:26:00
# 1199  goingtoinfinity  http://mariokrenn.wordpress.com 2020-04-22 23:40:00
# 1200      Terence Tao    http://www.math.ucla.edu/~tao 2020-04-23 07:34:00
# 1201          Rudolph                             None 2020-05-01 10:39:00
# 1202          Raphael                             None 2021-07-29 22:31:00
#
#                                            comment-href comment-id  \
# 0     https://terrytao.wordpress.com/2018/01/24/poly...     491743
# 1     https://terrytao.wordpress.com/2018/01/24/poly...     491746
# 2     https://terrytao.wordpress.com/2018/01/24/poly...     491750
# 3     https://terrytao.wordpress.com/2018/01/24/poly...     491753
# 4     https://terrytao.wordpress.com/2018/01/24/poly...     491759
# ...                                                 ...        ...
# 1198  https://terrytao.wordpress.com/2019/04/30/1107...     554539
# 1199  https://terrytao.wordpress.com/2019/04/30/1107...     554556
# 1200  https://terrytao.wordpress.com/2019/04/30/1107...     554639
# 1201  https://terrytao.wordpress.com/2019/04/30/1107...     556524
# 1202  https://terrytao.wordpress.com/2019/04/30/1107...     632149
#
#                                                 content  \
# 0     There seems to be a missing factor in the give...
# 1                                     Yes, t is missing
# 2     the differential inequality (1) can be written...
# 3     Well from the perspective of the numerical tea...
# 4     Although a precise horizontal(!) localization ...
# ...                                                 ...
# 1198                          “Just a small comment” :)
# 1199  Are there any ways to confirm the verification...
# 1200  This is a good question. I think with our curr...
# 1201  From the paper: “(…)The next entry in Table 1 ...
# 1202  Gaseous implies the existence of a complex con...
#
#                                               child-ids blog post-id  \
# 0                                              [491746]    T   10419
# 1                                                  None    T   10419
# 2     [491759, 491788, 491794, 491797, 491834, 49179...    T   10419
# 3     [491759, 491788, 491794, 491797, 491834, 49179...    T   10419
# 4     [491788, 491794, 491797, 491834, 491795, 49179...    T   10419
# ...                                                 ...  ...     ...
# 1198                                           [554639]    T   11075
# 1199                                           [554639]    T   11075
# 1200                                               None    T   11075
# 1201                                               None    T   11075
# 1202                                               None    T   11075
#
#                       id        in-reply-to  \
# 0      P15-T10419-491743                NaN
# 1     P15-Tr10419-491746  P15-T10419-491743
# 2      P15-T10419-491750                NaN
# 3      P15-T10419-491753                NaN
# 4     P15-Tr10419-491759  P15-T10419-491753
# ...                  ...                ...
# 1198  P15-Tr11075-554539  P15-T11075-554457
# 1199  P15-Tr11075-554556  P15-T11075-554457
# 1200  P15-Tr11075-554639  P15-T11075-554556
# 1201  P15-Tr11075-556524  P15-T11075-554457
# 1202   P15-T11075-632149                NaN
#
#                                        in-reply-to-href project-id
# 0                                                  None        P15
# 1     https://terrytao.wordpress.com/2018/01/24/poly...        P15
# 2                                                  None        P15
# 3                                                  None        P15
# 4     https://terrytao.wordpress.com/2018/01/24/poly...        P15
# ...                                                 ...        ...
# 1198  https://terrytao.wordpress.com/2019/04/30/1107...        P15
# 1199  https://terrytao.wordpress.com/2019/04/30/1107...        P15
# 1200  https://terrytao.wordpress.com/2019/04/30/1107...        P15
# 1201  https://terrytao.wordpress.com/2019/04/30/1107...        P15
# 1202                                               None        P15
#
# [1203 rows x 13 columns]

# %%
download_df(df_poly15, 'polymath15.json')

# %% [markdown]
# ## Polymath16

# %%
# Check: Dustin Mixon single thread
# df_dustin = scrape_thread('D', 'https://dustingmixon.wordpress.com/2018/04/14/polymath16-first-thread-simplifying-de-greys-graph/')
# df_dustin

# %%
poly16_urls = """
https://dustingmixon.wordpress.com/2018/04/14/polymath16-first-thread-simplifying-de-greys-graph/
https://dustingmixon.wordpress.com/2018/04/22/polymath16-second-thread-what-does-it-take-to-be-5-chromatic/
https://dustingmixon.wordpress.com/2018/05/01/polymath16-third-thread-is-6-chromatic-within-reach/
https://dustingmixon.wordpress.com/2018/05/05/polymath16-fourth-thread-applying-the-probabilistic-method/
https://dustingmixon.wordpress.com/2018/05/10/polymath16-fifth-thread-human-verifiable-proofs/
https://dustingmixon.wordpress.com/2018/05/29/polymath16-sixth-thread-wrestling-with-infinite-graphs/
https://dustingmixon.wordpress.com/2018/06/16/polymath16-seventh-thread-upper-bounds/
https://dustingmixon.wordpress.com/2018/06/24/polymath16-eighth-thread-more-upper-bounds/
https://dustingmixon.wordpress.com/2018/07/02/polymath16-ninth-thread-searching-for-a-6-coloring/
https://dustingmixon.wordpress.com/2018/08/28/polymath16-tenth-thread-open-sat-instances/
https://dustingmixon.wordpress.com/2018/09/14/polymath16-eleventh-thread-chromatic-numbers-of-planar-sets/
https://dustingmixon.wordpress.com/2019/03/23/polymath16-twelfth-thread-year-in-review-and-future-plans/
https://dustingmixon.wordpress.com/2019/07/08/polymath16-thirteenth-thread-bumping-the-deadline/
https://dustingmixon.wordpress.com/2019/08/05/polymath16-fourteenth-thread-automated-graph-minimization/
https://dustingmixon.wordpress.com/2019/12/12/polymath16-fifteenth-thread-writing-the-paper-and-chasing-down-loose-ends/
https://dustingmixon.wordpress.com/2020/05/11/polymath16-sixteenth-thread-writing-the-paper-and-chasing-down-loose-ends-ii/
https://dustingmixon.wordpress.com/2021/02/01/polymath16-seventeenth-thread-declaring-victory/
"""
poly16_thread_list = parse_urls(poly16_urls)

# %%
df_poly16 = scrape_project(poly16_thread_list)
df_poly16 = configure_columns('P16', df_poly16)
df_poly16
# Out:
#               author                    author-href                time  \
# 0           ag24ag24                           None 2018-04-14 14:11:00
# 1     Warren D Smith         http://rangevoting.org 2018-04-19 18:56:00
# 2     Warren D Smith         http://rangevoting.org 2018-04-19 19:02:00
# 3     Warren D Smith         http://rangevoting.org 2018-04-19 19:04:00
# 4     Lior Silberman  http://www.math.ubc.ca/~lior/ 2018-04-19 22:13:00
# ...              ...                            ...                 ...
# 2561      Jaan Parts                           None 2023-02-01 09:20:00
# 2562      Jaan Parts                           None 2023-02-01 14:41:00
# 2563      Jaan Parts                           None 2023-02-01 14:56:00
# 2564      Jaan Parts                           None 2023-02-04 06:38:00
# 2565      Jaan Parts                           None 2023-02-04 06:57:00
#
#                                            comment-href comment-id  \
# 0     https://dustingmixon.wordpress.com/2018/04/14/...       3812
# 1     https://dustingmixon.wordpress.com/2018/04/14/...       3917
# 2     https://dustingmixon.wordpress.com/2018/04/14/...       3918
# 3     https://dustingmixon.wordpress.com/2018/04/14/...       3919
# 4     https://dustingmixon.wordpress.com/2018/04/14/...       3922
# ...                                                 ...        ...
# 2561  https://dustingmixon.wordpress.com/2021/02/01/...      48652
# 2562  https://dustingmixon.wordpress.com/2021/02/01/...      48678
# 2563  https://dustingmixon.wordpress.com/2021/02/01/...      48679
# 2564  https://dustingmixon.wordpress.com/2021/02/01/...      48987
# 2565  https://dustingmixon.wordpress.com/2021/02/01/...      48993
#
#                                                 content  \
# 0     Many thanks Dustin! I am delighted to say that...
# 1     Some remarks about the Hadwiger-Nelson problem...
# 2     Hey, what the hell. Your worthless blog softwa...
# 3     Let me see if it actually says it now… –it did...
# 4     The problem is probably with angle brackets: H...
# ...                                                 ...
# 2561  The last sequence is described by the formula ...
# 2562  Tom’s formula for a 19-vertex generating graph...
# 2563  For a 31-vertex generating graph on five wheel...
# 2564  So, consider families of graphs of the form $G...
# 2565  Correction: $a_{2h-g}=\frac{f_g(h) 6^h}{(g+1)!...
#
#                                               child-ids blog post-id  \
# 0     [3917, 3918, 3919, 3922, 3923, 3924, 4269, 392...    D    4891
# 1                  [3918, 3919, 3922, 3923, 3924, 4269]    D    4891
# 2                                                  None    D    4891
# 3                                                  None    D    4891
# 4                                                  None    D    4891
# ...                                                 ...  ...     ...
# 2561                                               None    D    5088
# 2562                                               None    D    5088
# 2563                                               None    D    5088
# 2564                                            [48993]    D    5088
# 2565                                               None    D    5088
#
#                     id      in-reply-to  \
# 0       P16-D4891-3812              NaN
# 1      P16-Dr4891-3917   P16-D4891-3812
# 2      P16-Dr4891-3918   P16-D4891-3917
# 3      P16-Dr4891-3919   P16-D4891-3917
# 4      P16-Dr4891-3922   P16-D4891-3917
# ...                ...              ...
# 2561  P16-Dr5088-48652  P16-D5088-48625
# 2562  P16-Dr5088-48678  P16-D5088-48625
# 2563  P16-Dr5088-48679  P16-D5088-48625
# 2564  P16-Dr5088-48987  P16-D5088-48587
# 2565  P16-Dr5088-48993  P16-D5088-48987
#
#                                        in-reply-to-href project-id
# 0                                                  None        P16
# 1     https://dustingmixon.wordpress.com/2018/04/14/...        P16
# 2     https://dustingmixon.wordpress.com/2018/04/14/...        P16
# 3     https://dustingmixon.wordpress.com/2018/04/14/...        P16
# 4     https://dustingmixon.wordpress.com/2018/04/14/...        P16
# ...                                                 ...        ...
# 2561  https://dustingmixon.wordpress.com/2021/02/01/...        P16
# 2562  https://dustingmixon.wordpress.com/2021/02/01/...        P16
# 2563  https://dustingmixon.wordpress.com/2021/02/01/...        P16
# 2564  https://dustingmixon.wordpress.com/2021/02/01/...        P16
# 2565  https://dustingmixon.wordpress.com/2021/02/01/...        P16
#
# [2566 rows x 13 columns]

# %%
download_df(df_poly16, 'polymath16.json')

# %% [markdown]
# ## Mini1

# %%
mini1_urls = """
https://terrytao.wordpress.com/2009/07/20/imo-2009-q6-as-a-mini-polymath-project/
https://terrytao.wordpress.com/2009/07/21/imo-2009-q6-mini-polymath-project-cont/
"""
mini1_thread_list = parse_urls(mini1_urls)

df_mini1 = scrape_project(mini1_thread_list)
df_mini1 = configure_columns('M1', df_mini1)
df_mini1
# Out:
#            author author-href                time  \
# 0            jens        None 2009-07-21 05:35:00
# 1    David Escott        None 2009-07-21 07:14:00
# 2    David Escott        None 2009-07-21 07:15:00
# 3    David Escott        None 2009-07-21 07:15:00
# 4    David Escott        None 2009-07-21 07:16:00
# ..            ...         ...                 ...
# 331            ar        None 2009-07-21 13:16:00
# 332   Mark Bennet        None 2009-07-21 13:17:00
# 333            ar        None 2009-07-21 13:22:00
# 334  David Speyer        None 2009-07-21 14:08:00
# 335          jens        None 2009-07-21 14:14:00
#
#                                           comment-href comment-id  \
# 0    https://terrytao.wordpress.com/2009/07/20/imo-...      40377
# 1    https://terrytao.wordpress.com/2009/07/20/imo-...      40384
# 2    https://terrytao.wordpress.com/2009/07/20/imo-...      40385
# 3    https://terrytao.wordpress.com/2009/07/20/imo-...      40386
# 4    https://terrytao.wordpress.com/2009/07/20/imo-...      40388
# ..                                                 ...        ...
# 331  https://terrytao.wordpress.com/2009/07/21/imo-...      40481
# 332  https://terrytao.wordpress.com/2009/07/21/imo-...      40482
# 333  https://terrytao.wordpress.com/2009/07/21/imo-...      40483
# 334  https://terrytao.wordpress.com/2009/07/21/imo-...      40484
# 335  https://terrytao.wordpress.com/2009/07/21/imo-...      40485
#
#                                                content child-ids blog post-id  \
# 0        140. to 139 oh yes, I see the problem, thanks      None    T    2495
# 1    141. I’m suspicious that Terry is removing pos...      None    T    2495
# 2    141a. Given a set where the Grasshopper can re...      None    T    2495
# 3    141b. Speyer (2) mentioned a minimal size need...      None    T    2495
# 4    141c. Final observation. The beginning an endi...      None    T    2495
# ..                                                 ...       ...  ...     ...
# 331  230. @sw (201). Regarding the graph approach, ...      None    T    2520
# 332  223 David – my equivalence relation can reduce...      None    T    2520
# 333  232. Let me write the graph restatment again. ...      None    T    2520
# 334  233 ar: If I understand you correctly, what yo...      None    T    2520
# 335  233. Just a general thought on “almost complet...      None    T    2520
#
#                  id in-reply-to in-reply-to-href project-id
# 0    M1-T2495-40377         NaN             None         M1
# 1    M1-T2495-40384         NaN             None         M1
# 2    M1-T2495-40385         NaN             None         M1
# 3    M1-T2495-40386         NaN             None         M1
# 4    M1-T2495-40388         NaN             None         M1
# ..              ...         ...              ...        ...
# 331  M1-T2520-40481         NaN             None         M1
# 332  M1-T2520-40482         NaN             None         M1
# 333  M1-T2520-40483         NaN             None         M1
# 334  M1-T2520-40484         NaN             None         M1
# 335  M1-T2520-40485         NaN             None         M1
#
# [336 rows x 13 columns]

# %%
download_df(df_mini1, 'mini1.json')

# %% [markdown]
# ## Mini2

# %%
df_mini2 = scrape_thread('P', 'http://polymathprojects.org/2010/07/08/minipolymath2-project-imo-2010-q5/')
df_mini2 = configure_columns('M2', df_mini2)
df_mini2
# Out:
#              author author-href                time  \
# 0        Aaron Hill        None 2010-07-08 16:13:00
# 1              Greg        None 2010-07-08 16:19:00
# 2                oz        None 2010-07-08 16:14:00
# 3        Aaron Hill        None 2010-07-08 16:35:00
# 4    Alexandr Kazda        None 2010-07-08 16:45:00
# ..              ...         ...                 ...
# 115     Mark Bennet        None 2010-07-12 16:42:00
# 116            John        None 2010-07-11 02:01:00
# 117     Mark Bennet        None 2010-07-12 22:02:00
# 118     Mark Bennet        None 2010-07-16 17:16:00
# 119     Mark Bennet        None 2010-07-16 21:13:00
#
#                                           comment-href comment-id  \
# 0    http://polymathprojects.org/2010/07/08/minipol...       2110
# 1    http://polymathprojects.org/2010/07/08/minipol...       2113
# 2    http://polymathprojects.org/2010/07/08/minipol...       2111
# 3    http://polymathprojects.org/2010/07/08/minipol...       2116
# 4    http://polymathprojects.org/2010/07/08/minipol...       2121
# ..                                                 ...        ...
# 115  http://polymathprojects.org/2010/07/08/minipol...       2255
# 116  http://polymathprojects.org/2010/07/08/minipol...       2247
# 117  http://polymathprojects.org/2010/07/08/minipol...       2257
# 118  http://polymathprojects.org/2010/07/08/minipol...       2263
# 119  http://polymathprojects.org/2010/07/08/minipol...       2265
#
#                                                content  \
# 0    By the first rule we can say that a coin in B_...
# 1    – more precisely, the total worth goes up when...
# 2    Trivial observation: whenever the left-most bo...
# 3    This seems to imply that we cannot get arbitra...
# 4    We can probably construct some sort of recursi...
# ..                                                 ...
# 115  I think I can see the pattern here. [1,1,1,1,1...
# 116  Maybe there’s a a way to solve using conserved...
# 117  Every extra place to the left adds an extra le...
# 118  There are various ways of getting a recursion ...
# 119  I’ve been working on the biggest numbers you c...
#
#                                 child-ids blog post-id             id  \
# 0                                  [2113]    P     175   M2-P175-2110
# 1                                    None    P     175  M2-Pr175-2113
# 2    [2116, 2121, 2117, 2119, 2127, 2144]    P     175   M2-P175-2111
# 3                                  [2121]    P     175  M2-Pr175-2116
# 4                                    None    P     175  M2-Pr175-2121
# ..                                    ...  ...     ...            ...
# 115                                  None    P     175  M2-Pr175-2255
# 116                                [2257]    P     175   M2-P175-2247
# 117                                  None    P     175  M2-Pr175-2257
# 118                                  None    P     175   M2-P175-2263
# 119                                  None    P     175   M2-P175-2265
#
#       in-reply-to                                   in-reply-to-href  \
# 0             NaN                                               None
# 1    M2-P175-2110  http://polymathprojects.org/2010/07/08/minipol...
# 2             NaN                                               None
# 3    M2-P175-2111  http://polymathprojects.org/2010/07/08/minipol...
# 4    M2-P175-2116  http://polymathprojects.org/2010/07/08/minipol...
# ..            ...                                                ...
# 115  M2-P175-2253  http://polymathprojects.org/2010/07/08/minipol...
# 116           NaN                                               None
# 117  M2-P175-2247  http://polymathprojects.org/2010/07/08/minipol...
# 118           NaN                                               None
# 119           NaN                                               None
#
#     project-id
# 0           M2
# 1           M2
# 2           M2
# 3           M2
# 4           M2
# ..         ...
# 115         M2
# 116         M2
# 117         M2
# 118         M2
# 119         M2
#
# [120 rows x 13 columns]

# %%
download_df(df_mini2, 'mini2.json')

# %% [markdown]
# ## Mini3

# %%
df_mini3 = scrape_thread('P', 'https://polymathprojects.org/2011/07/19/minipolymath3-project-2011-imo/')
df_mini3 = configure_columns('M3', df_mini3)
df_mini3
# Out:
#                       author                  author-href                time  \
# 0             Richard McCart                         None 2011-08-22 03:52:00
# 1                        Gal                         None 2011-07-19 20:07:00
# 2                       Garf                         None 2011-07-19 20:23:00
# 3                        Gal                         None 2011-07-19 20:37:00
# 4                        Gal                         None 2011-07-19 20:56:00
# ..                       ...                          ...                 ...
# 141                     twio    http://twio.wordpress.com 2012-02-14 13:24:00
# 142                   mkhida  http://mkhida.wordpress.com 2012-03-28 14:09:00
# 143                  brandon                         None 2012-04-02 05:21:00
# 144                     twio    http://twio.wordpress.com 2012-04-02 13:20:00
# 145  Christian Wieczerkowski      http://wieczerkowski.de 2012-10-17 15:25:00
#
#                                           comment-href comment-id  \
# 0    https://polymathprojects.org/2011/07/19/minipo...       3501
# 1    https://polymathprojects.org/2011/07/19/minipo...       3305
# 2    https://polymathprojects.org/2011/07/19/minipo...       3323
# 3    https://polymathprojects.org/2011/07/19/minipo...       3341
# 4    https://polymathprojects.org/2011/07/19/minipo...       3368
# ..                                                 ...        ...
# 141  https://polymathprojects.org/2011/07/19/minipo...       5095
# 142  https://polymathprojects.org/2011/07/19/minipo...       5337
# 143  https://polymathprojects.org/2011/07/19/minipo...       5356
# 144  https://polymathprojects.org/2011/07/19/minipo...       5359
# 145  https://polymathprojects.org/2011/07/19/minipo...      10822
#
#                                                content  \
# 0    Could you start off with a random point in the...
# 1    Connecting the dots: At the point where the pi...
# 2    Nice. We need only to consider the times when ...
# 3    Isn’t there always a cycle that spans all the ...
# 4    For example, the restriction on how the next p...
# ..                                                 ...
# 141  Just encountered this site, and this problem, ...
# 142  sorry for my English,I have just a remark on t...
# 143  Lemma 1: Let set A have this property Let T be...
# 144  brandon wrote: Let set A have this property Le...
# 145  Not sure where this blog really is but it seem...
#
#                                       child-ids blog post-id             id  \
# 0                                          None    P     249   M3-P249-3501
# 1    [3323, 3341, 3368, 3399, 3332, 3342, 3348]    P     249   M3-P249-3305
# 2                            [3341, 3368, 3399]    P     249  M3-Pr249-3323
# 3                                  [3368, 3399]    P     249  M3-Pr249-3341
# 4                                        [3399]    P     249  M3-Pr249-3368
# ..                                          ...  ...     ...            ...
# 141                                        None    P     249   M3-P249-5095
# 142                                        None    P     249   M3-P249-5337
# 143                                      [5359]    P     249   M3-P249-5356
# 144                                        None    P     249  M3-Pr249-5359
# 145                                        None    P     249  M3-P249-10822
#
#       in-reply-to                                   in-reply-to-href  \
# 0             NaN                                               None
# 1             NaN                                               None
# 2    M3-P249-3305  https://polymathprojects.org/2011/07/19/minipo...
# 3    M3-P249-3323  https://polymathprojects.org/2011/07/19/minipo...
# 4    M3-P249-3341  https://polymathprojects.org/2011/07/19/minipo...
# ..            ...                                                ...
# 141           NaN                                               None
# 142           NaN                                               None
# 143           NaN                                               None
# 144  M3-P249-5356  https://polymathprojects.org/2011/07/19/minipo...
# 145           NaN                                               None
#
#     project-id
# 0           M3
# 1           M3
# 2           M3
# 3           M3
# 4           M3
# ..         ...
# 141         M3
# 142         M3
# 143         M3
# 144         M3
# 145         M3
#
# [146 rows x 13 columns]

# %%
download_df(df_mini3, 'mini3.json')

# %% [markdown]
# ## Mini4

# %%
df_mini4 = scrape_thread('P', 'https://polymathprojects.org/2012/07/12/minipolymath4-project-imo-2012-q3/')
df_mini4 = configure_columns('M4', df_mini4)
df_mini4
# Out:
#                author                             author-href  \
# 0                 Bob                                    None
# 1          Mihai Nica    http://probabilitynica.wordpress.com
# 2              Jaakko                                    None
# 3                 Jon                                    None
# 4      Vladimir Nesov                                    None
# ..                ...                                     ...
# 76       akash chayan                                    None
# 77  Gagik Amirkhanyan             http://gagika.wordpress.com
# 78        Terence Tao           http://www.math.ucla.edu/~tao
# 79  prateekchandrajha  http://prateekchandrajha.wordpress.com
# 80          Anonymous                                    None
#
#                   time                                       comment-href  \
# 0  2012-07-12 22:11:00  https://polymathprojects.org/2012/07/12/minipo...
# 1  2012-07-12 22:17:00  https://polymathprojects.org/2012/07/12/minipo...
# 2  2012-07-12 22:19:00  https://polymathprojects.org/2012/07/12/minipo...
# 3  2012-07-12 22:22:00  https://polymathprojects.org/2012/07/12/minipo...
# 4  2012-07-12 22:34:00  https://polymathprojects.org/2012/07/12/minipo...
# ..                 ...                                                ...
# 76 2012-07-13 19:53:00  https://polymathprojects.org/2012/07/12/minipo...
# 77 2012-07-13 20:14:00  https://polymathprojects.org/2012/07/12/minipo...
# 78 2012-07-13 19:56:00  https://polymathprojects.org/2012/07/12/minipo...
# 79 2012-07-30 22:58:00  https://polymathprojects.org/2012/07/12/minipo...
# 80 2012-08-22 15:27:00  https://polymathprojects.org/2012/07/12/minipo...
#
#    comment-id                                            content  \
# 0        7557  Obvious observations: It seems for part 1 we h...
# 1        7558  The fact that player A has to choose the numbe...
# 2        7559  Are there any results from Ramsey theory or re...
# 3        7560  Obvious: If we choose sets S_p to be of the fo...
# 4        7570  More generally, for any partition of some set ...
# ..        ...                                                ...
# 76       7690  The game can be re-formulated in an equivalent...
# 77       7696  I think it’s correct solution, just in the def...
# 78       7691  Dear all, As this thread is becoming quite ful...
# 79       8392  Reblogged this on Wikipedia Afficianado and co...
# 80       9479  1) for the case of k consecutive responses one...
#
#        child-ids blog post-id             id   in-reply-to  \
# 0           None    P     304   M4-P304-7557           NaN
# 1           None    P     304   M4-P304-7558           NaN
# 2           None    P     304   M4-P304-7559           NaN
# 3   [7570, 7579]    P     304   M4-P304-7560           NaN
# 4         [7579]    P     304  M4-Pr304-7570  M4-P304-7560
# ..           ...  ...     ...            ...           ...
# 76        [7696]    P     304   M4-P304-7690           NaN
# 77          None    P     304  M4-Pr304-7696  M4-P304-7690
# 78          None    P     304   M4-P304-7691           NaN
# 79          None    P     304   M4-P304-8392           NaN
# 80          None    P     304   M4-P304-9479           NaN
#
#                                      in-reply-to-href project-id
# 0                                                None         M4
# 1                                                None         M4
# 2                                                None         M4
# 3                                                None         M4
# 4   https://polymathprojects.org/2012/07/12/minipo...         M4
# ..                                                ...        ...
# 76                                               None         M4
# 77  https://polymathprojects.org/2012/07/12/minipo...         M4
# 78                                               None         M4
# 79                                               None         M4
# 80                                               None         M4
#
# [81 rows x 13 columns]

# %%
download_df(df_mini4, 'mini4.json')
